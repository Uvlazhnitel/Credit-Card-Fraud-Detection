# %%
import numpy as np, pandas as pd
from pathlib import Path
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve, auc
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.metrics import roc_curve, roc_auc_score

RANDOM_STATE = 42
TARGET_COL = "Class"
TEST_SIZE = 0.2

# %%
PROJECT_ROOT = Path("..").resolve()
DATA_RAW = PROJECT_ROOT / "data" / "raw"
SPLITS_DIR = PROJECT_ROOT / "data" / "splits"
REPORTS_DIR = PROJECT_ROOT / "reports"

# Ensure the directory exists
DATA_RAW.mkdir(parents=True, exist_ok=True)
SPLITS_DIR.mkdir(parents=True, exist_ok=True)
REPORTS_DIR.mkdir(parents=True, exist_ok=True)

# Check if the file exists before reading
csv_file = DATA_RAW / "creditcard.csv"
if csv_file.exists():
    df = pd.read_csv(csv_file, low_memory=False)  # Suppress DtypeWarning
    df.head(10)
else:
    print(f"File not found: {csv_file}")

# %%
X = df.drop(columns=[TARGET_COL])
y = df[TARGET_COL]

# %%
train_idx = np.load(SPLITS_DIR / "X_train.npy")

X_train = X.loc[train_idx].copy()
y_train = y.loc[train_idx].copy()

# %%
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, FunctionTransformer
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.ensemble import HistGradientBoostingClassifier

v_columns = [f"V{i}" for i in range(1, 29)]
amount_col = ["Amount"]
time_col = ["Time"]

SECONDS_IN_DAY = 86400

def time_cyc_features(X):
    t = (X % SECONDS_IN_DAY) / SECONDS_IN_DAY
    return np.hstack([np.sin(2 * np.pi * t), np.cos(2 * np.pi * t)])

def coerce_numeric_df(X):
    X = X.copy()
    for c in X.columns:
        X[c] = pd.to_numeric(X[c], errors="coerce")
    return X

to_numeric = FunctionTransformer(coerce_numeric_df, validate=False)

amount_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("log1p", FunctionTransformer(np.log1p, validate=True)),
    ("scaler", StandardScaler()),
])

v_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler()),
])

time_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("cyc", FunctionTransformer(time_cyc_features, validate=True)),
    ("scaler", StandardScaler()),
])

preprocessor = ColumnTransformer(
    transformers=[
        ("amount", amount_transformer, amount_col),
        ("time", time_transformer, time_col),
        ("v", v_transformer, v_columns),
    ],
    remainder="drop"
)

model = Pipeline(steps=[
    ("to_numeric", to_numeric),
    ("preprocessor", preprocessor),
    ("classifier", HistGradientBoostingClassifier(random_state=RANDOM_STATE
    ))
])

model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('to_numeric',
#                  FunctionTransformer(func=<function coerce_numeric_df at 0x11f549440>)),
#                 ('preprocessor',
#                  ColumnTransformer(transformers=[('amount',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('log1p',
#                                                                    FunctionTransformer(func=<ufunc 'log1p'>,
#                                                                                        validate=True)),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Amount']),
#                                                  ('time',
#                                                   Pipeline(steps=[('...
#                                                   ['Time']),
#                                                  ('v',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['V1', 'V2', 'V3', 'V4', 'V5',
#                                                    'V6', 'V7', 'V8', 'V9',
#                                                    'V10', 'V11', 'V12', 'V13',
#                                                    'V14', 'V15', 'V16', 'V17',
#                                                    'V18', 'V19', 'V20', 'V21',
#                                                    'V22', 'V23', 'V24', 'V25',
#                                                    'V26', 'V27', 'V28'])])),
#                 ('classifier',
#                  HistGradientBoostingClassifier(class_weight='balanced',
#                                                 random_state=42))])

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_predict

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)

y_pred = cross_val_predict(model, X_train, y_train, cv=skf)

oof_proba = cross_val_predict(model, X_train, y_train, cv=skf, method="predict_proba")[:, 1]

# %%
precision, recall, thresholds = precision_recall_curve(y_train, oof_proba)
thr_ext = np.r_[0.0, thresholds]
print(len(precision), len(recall), len(thr_ext))
# Out:
# 43326 43326 43326

# %%
import sys
from pathlib import Path

# Add the parent directory of 'src' to sys.path
sys.path.append(str(PROJECT_ROOT))

from src.choose_thresholds import choose_threshold_max_recall_at_fpr

chosen_thr, strategy, metrics = choose_threshold_max_recall_at_fpr(
    y_true=y_train,
    proba=oof_proba,
    max_fpr=0.001
)
print(f"Chosen threshold: {chosen_thr}, strategy: {strategy}")
print("Metrics at chosen threshold:")
for metric_name, metric_value in metrics.items():
    print(f"{metric_name}: {round(metric_value, 4)}")
# Out:
# Chosen threshold: 0.7274798704449073, strategy: Max recall with FPR≤0.0010
# Metrics at chosen threshold:
# threshold: 0.7275
# fpr: 0.001
# recall: 0.8173
# precision: 0.5876
# f1: 0.6837

# %%
cm = confusion_matrix(y_train, (oof_proba >= chosen_thr).astype(int))
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[227225    226]
#  [    72    322]]

# %%
#PR curve for chosen threshold

plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label="Precision-Recall Curve")
plt.scatter(metrics['recall'], metrics['precision'], color='red', label='Chosen Threshold', zorder=5)
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve with Chosen Threshold (HGB)")
plt.legend()
plt.grid()
plt.savefig(REPORTS_DIR / "pr_curve_chosen_threshold_hgb.png")
plt.show()

#Recall@FixedPRecision graph

plt.figure(figsize=(8, 6))
plt.plot(thr_ext, recall, label="Recall vs Threshold")
plt.scatter(chosen_thr, metrics['recall'], color='red', label='Chosen Threshold', zorder=5)
plt.xlabel("Threshold")
plt.ylabel("Recall")
plt.title("Recall vs Threshold with Chosen Threshold (HGB)")
plt.legend()
plt.grid()
plt.savefig(REPORTS_DIR / "recall_vs_threshold_chosen_threshold_hgb.png")

# %%
import numpy as np
from scipy.stats import uniform, randint

from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import roc_curve
from sklearn.metrics import make_scorer
from sklearn.model_selection import StratifiedKFold

# --- 1) Param search space (HGB) ---
param_distributions = {
    "classifier__learning_rate": uniform(0.01, 0.19),
    "classifier__max_leaf_nodes": randint(15, 50),
    "classifier__min_samples_leaf": randint(5, 30),
    "classifier__max_iter": randint(100, 600),
}

# --- 2) Custom scorer: maximize recall (TPR) subject to FPR <= max_fpr ---
def recall_at_max_fpr(y_true, y_score, max_fpr=0.001, **kwargs):
    """
    y_score is expected to be probability of positive class (fraud).
    **kwargs is required because newer sklearn may pass extra kwargs (e.g., needs_proba).
    """
    fpr, tpr, _ = roc_curve(y_true, y_score)
    ok = np.where(fpr <= max_fpr)[0]
    return float(np.max(tpr[ok])) if ok.size else 0.0

recall_fpr_0p1_scorer = make_scorer(
    recall_at_max_fpr,
    needs_proba=True,   # tells sklearn to pass predict_proba output
    max_fpr=0.001       # passed to recall_at_max_fpr as kwarg
)

# --- 3) Multi-metric scoring; refit by your KPI ---
scoring = {
    "roc_auc": "roc_auc",
    "pr_auc": "average_precision",
    "recall_fpr_0p1": recall_fpr_0p1_scorer,
}

# If you haven't defined skf yet, define it like this:
# (shuffle is important for randomized search reproducibility)
# skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)

random_search = RandomizedSearchCV(
    estimator=model,
    param_distributions=param_distributions,
    n_iter=40,
    scoring=scoring,
    refit="recall_fpr_0p1",
    n_jobs=-1,
    cv=skf,
    random_state=RANDOM_STATE,
    verbose=2,
    error_score="raise",  # fail fast if something else breaks
)

# --- 4) class imbalance handling for HGB via sample_weight ---
# If you want "balanced" behavior for HistGradientBoostingClassifier, use sample weights:
USE_SAMPLE_WEIGHT = True  # set True if you want it
W_POS = 200              # try 50, 100, 200

if USE_SAMPLE_WEIGHT:
    sample_weight = np.where(y_train == 1, W_POS, 1.0)
    random_search.fit(X_train, y_train, classifier__sample_weight=sample_weight)
else:
    random_search.fit(X_train, y_train)

print("Best Parameters:", random_search.best_params_)
print("Best Score (Recall at FPR 0.1%):", random_search.best_score_)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV] END classifier__learning_rate=0.08116262258099886, classifier__max_iter=448, classifier__max_leaf_nodes=29, classifier__min_samples_leaf=15; total time=   5.0s
# [CV] END classifier__learning_rate=0.08116262258099886, classifier__max_iter=448, classifier__max_leaf_nodes=29, classifier__min_samples_leaf=15; total time=   5.3s
# [CV] END classifier__learning_rate=0.15814129005182617, classifier__max_iter=120, classifier__max_leaf_nodes=33, classifier__min_samples_leaf=27; total time=   5.1s
# [CV] END classifier__learning_rate=0.08116262258099886, classifier__max_iter=448, classifier__max_leaf_nodes=29, classifier__min_samples_leaf=15; total time=   5.7s
# [CV] END classifier__learning_rate=0.08116262258099886, classifier__max_iter=448, classifier__max_leaf_nodes=29, classifier__min_samples_leaf=15; total time=   5.8s
# [CV] END classifier__learning_rate=0.08116262258099886, classifier__max_iter=448, classifier__max_leaf_nodes=29, classifier__min_samples_leaf=15; total time=   5.9s
# [CV] END classifier__learning_rate=0.15814129005182617, classifier__max_iter=120, classifier__max_leaf_nodes=33, classifier__min_samples_leaf=27; total time=   5.6s
# [CV] END classifier__learning_rate=0.15814129005182617, classifier__max_iter=120, classifier__max_leaf_nodes=33, classifier__min_samples_leaf=27; total time=   5.5s
# [CV] END classifier__learning_rate=0.15814129005182617, classifier__max_iter=120, classifier__max_leaf_nodes=33, classifier__min_samples_leaf=27; total time=   5.4s
# [CV] END classifier__learning_rate=0.15814129005182617, classifier__max_iter=120, classifier__max_leaf_nodes=33, classifier__min_samples_leaf=27; total time=   5.8s
# [CV] END classifier__learning_rate=0.021035886311957897, classifier__max_iter=187, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=7; total time=   4.1s
# [CV] END classifier__learning_rate=0.021035886311957897, classifier__max_iter=187, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=7; total time=   4.1s
# [CV] END classifier__learning_rate=0.021035886311957897, classifier__max_iter=187, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=7; total time=   4.6s
# [CV] END classifier__learning_rate=0.021035886311957897, classifier__max_iter=187, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=7; total time=   4.0s
# [CV] END classifier__learning_rate=0.013911053916202464, classifier__max_iter=357, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=16; total time=   4.1s
# [CV] END classifier__learning_rate=0.021035886311957897, classifier__max_iter=187, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=7; total time=   4.6s
# [CV] END classifier__learning_rate=0.013911053916202464, classifier__max_iter=357, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=16; total time=   4.8s
# [CV] END classifier__learning_rate=0.013911053916202464, classifier__max_iter=357, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=16; total time=   4.6s
# [CV] END classifier__learning_rate=0.013911053916202464, classifier__max_iter=357, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=16; total time=   4.2s
# [CV] END classifier__learning_rate=0.013911053916202464, classifier__max_iter=357, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=16; total time=   4.3s
# [CV] END classifier__learning_rate=0.18832501471299254, classifier__max_iter=485, classifier__max_leaf_nodes=35, classifier__min_samples_leaf=5; total time=   4.5s
# [CV] END classifier__learning_rate=0.18832501471299254, classifier__max_iter=485, classifier__max_leaf_nodes=35, classifier__min_samples_leaf=5; total time=   5.4s
# [CV] END classifier__learning_rate=0.18832501471299254, classifier__max_iter=485, classifier__max_leaf_nodes=35, classifier__min_samples_leaf=5; total time=   5.9s
# [CV] END classifier__learning_rate=0.18832501471299254, classifier__max_iter=485, classifier__max_leaf_nodes=35, classifier__min_samples_leaf=5; total time=   5.8s
# [CV] END classifier__learning_rate=0.06780602616231217, classifier__max_iter=121, classifier__max_leaf_nodes=39, classifier__min_samples_leaf=21; total time=   5.9s
# [CV] END classifier__learning_rate=0.18832501471299254, classifier__max_iter=485, classifier__max_leaf_nodes=35, classifier__min_samples_leaf=5; total time=   6.3s
# [CV] END classifier__learning_rate=0.06780602616231217, classifier__max_iter=121, classifier__max_leaf_nodes=39, classifier__min_samples_leaf=21; total time=   6.1s
# [CV] END classifier__learning_rate=0.06780602616231217, classifier__max_iter=121, classifier__max_leaf_nodes=39, classifier__min_samples_leaf=21; total time=   6.1s
# [CV] END classifier__learning_rate=0.06780602616231217, classifier__max_iter=121, classifier__max_leaf_nodes=39, classifier__min_samples_leaf=21; total time=   6.5s
# [CV] END classifier__learning_rate=0.06780602616231217, classifier__max_iter=121, classifier__max_leaf_nodes=39, classifier__min_samples_leaf=21; total time=   6.6s
# [CV] END classifier__learning_rate=0.10970718544909393, classifier__max_iter=269, classifier__max_leaf_nodes=42, classifier__min_samples_leaf=20; total time=   5.1s
# [CV] END classifier__learning_rate=0.10970718544909393, classifier__max_iter=269, classifier__max_leaf_nodes=42, classifier__min_samples_leaf=20; total time=   5.4s
# [CV] END classifier__learning_rate=0.10970718544909393, classifier__max_iter=269, classifier__max_leaf_nodes=42, classifier__min_samples_leaf=20; total time=   4.9s
# [CV] END classifier__learning_rate=0.054226554681757806, classifier__max_iter=545, classifier__max_leaf_nodes=17, classifier__min_samples_leaf=9; total time=   4.2s
# [CV] END classifier__learning_rate=0.10970718544909393, classifier__max_iter=269, classifier__max_leaf_nodes=42, classifier__min_samples_leaf=20; total time=   4.5s
# [CV] END classifier__learning_rate=0.10970718544909393, classifier__max_iter=269, classifier__max_leaf_nodes=42, classifier__min_samples_leaf=20; total time=   4.5s
# [CV] END classifier__learning_rate=0.054226554681757806, classifier__max_iter=545, classifier__max_leaf_nodes=17, classifier__min_samples_leaf=9; total time=   3.8s
# [CV] END classifier__learning_rate=0.054226554681757806, classifier__max_iter=545, classifier__max_leaf_nodes=17, classifier__min_samples_leaf=9; total time=   4.2s
# [CV] END classifier__learning_rate=0.054226554681757806, classifier__max_iter=545, classifier__max_leaf_nodes=17, classifier__min_samples_leaf=9; total time=   3.8s
# [CV] END classifier__learning_rate=0.054226554681757806, classifier__max_iter=545, classifier__max_leaf_nodes=17, classifier__min_samples_leaf=9; total time=   4.5s
# [CV] END classifier__learning_rate=0.1254335218612733, classifier__max_iter=120, classifier__max_leaf_nodes=23, classifier__min_samples_leaf=11; total time=   4.4s
# [CV] END classifier__learning_rate=0.1254335218612733, classifier__max_iter=120, classifier__max_leaf_nodes=23, classifier__min_samples_leaf=11; total time=   4.7s
# [CV] END classifier__learning_rate=0.1254335218612733, classifier__max_iter=120, classifier__max_leaf_nodes=23, classifier__min_samples_leaf=11; total time=   5.2s
# [CV] END classifier__learning_rate=0.1254335218612733, classifier__max_iter=120, classifier__max_leaf_nodes=23, classifier__min_samples_leaf=11; total time=   5.0s
# [CV] END classifier__learning_rate=0.1254335218612733, classifier__max_iter=120, classifier__max_leaf_nodes=23, classifier__min_samples_leaf=11; total time=   5.2s
# [CV] END classifier__learning_rate=0.01252034262037464, classifier__max_iter=188, classifier__max_leaf_nodes=28, classifier__min_samples_leaf=22; total time=   4.9s
# [CV] END classifier__learning_rate=0.01252034262037464, classifier__max_iter=188, classifier__max_leaf_nodes=28, classifier__min_samples_leaf=22; total time=   5.3s
# [CV] END classifier__learning_rate=0.01252034262037464, classifier__max_iter=188, classifier__max_leaf_nodes=28, classifier__min_samples_leaf=22; total time=   5.3s
# [CV] END classifier__learning_rate=0.01252034262037464, classifier__max_iter=188, classifier__max_leaf_nodes=28, classifier__min_samples_leaf=22; total time=   5.6s
# [CV] END classifier__learning_rate=0.01252034262037464, classifier__max_iter=188, classifier__max_leaf_nodes=28, classifier__min_samples_leaf=22; total time=   4.6s
# [CV] END classifier__learning_rate=0.08322913548258405, classifier__max_iter=445, classifier__max_leaf_nodes=16, classifier__min_samples_leaf=24; total time=   5.1s
# [CV] END classifier__learning_rate=0.08322913548258405, classifier__max_iter=445, classifier__max_leaf_nodes=16, classifier__min_samples_leaf=24; total time=   4.9s
# [CV] END classifier__learning_rate=0.08322913548258405, classifier__max_iter=445, classifier__max_leaf_nodes=16, classifier__min_samples_leaf=24; total time=   5.2s
# [CV] END classifier__learning_rate=0.08322913548258405, classifier__max_iter=445, classifier__max_leaf_nodes=16, classifier__min_samples_leaf=24; total time=   5.5s
# [CV] END classifier__learning_rate=0.08322913548258405, classifier__max_iter=445, classifier__max_leaf_nodes=16, classifier__min_samples_leaf=24; total time=   5.8s
# [CV] END classifier__learning_rate=0.05579483854494223, classifier__max_iter=543, classifier__max_leaf_nodes=21, classifier__min_samples_leaf=16; total time=   5.0s
# [CV] END classifier__learning_rate=0.05579483854494223, classifier__max_iter=543, classifier__max_leaf_nodes=21, classifier__min_samples_leaf=16; total time=   4.8s
# [CV] END classifier__learning_rate=0.05579483854494223, classifier__max_iter=543, classifier__max_leaf_nodes=21, classifier__min_samples_leaf=16; total time=   5.2s
# [CV] END classifier__learning_rate=0.05579483854494223, classifier__max_iter=543, classifier__max_leaf_nodes=21, classifier__min_samples_leaf=16; total time=   5.0s
# [CV] END classifier__learning_rate=0.05579483854494223, classifier__max_iter=543, classifier__max_leaf_nodes=21, classifier__min_samples_leaf=16; total time=   5.0s
# [CV] END classifier__learning_rate=0.10408361292114134, classifier__max_iter=530, classifier__max_leaf_nodes=49, classifier__min_samples_leaf=18; total time=   4.3s
# [CV] END classifier__learning_rate=0.10408361292114134, classifier__max_iter=530, classifier__max_leaf_nodes=49, classifier__min_samples_leaf=18; total time=   3.8s
# [CV] END classifier__learning_rate=0.10408361292114134, classifier__max_iter=530, classifier__max_leaf_nodes=49, classifier__min_samples_leaf=18; total time=   3.9s
# [CV] END classifier__learning_rate=0.10408361292114134, classifier__max_iter=530, classifier__max_leaf_nodes=49, classifier__min_samples_leaf=18; total time=   4.0s
# [CV] END classifier__learning_rate=0.10408361292114134, classifier__max_iter=530, classifier__max_leaf_nodes=49, classifier__min_samples_leaf=18; total time=   4.1s
# [CV] END classifier__learning_rate=0.08430151543891574, classifier__max_iter=149, classifier__max_leaf_nodes=18, classifier__min_samples_leaf=6; total time=   3.9s
# [CV] END classifier__learning_rate=0.08430151543891574, classifier__max_iter=149, classifier__max_leaf_nodes=18, classifier__min_samples_leaf=6; total time=   4.1s
# [CV] END classifier__learning_rate=0.08430151543891574, classifier__max_iter=149, classifier__max_leaf_nodes=18, classifier__min_samples_leaf=6; total time=   3.8s
# [CV] END classifier__learning_rate=0.08430151543891574, classifier__max_iter=149, classifier__max_leaf_nodes=18, classifier__min_samples_leaf=6; total time=   4.1s
# [CV] END classifier__learning_rate=0.08430151543891574, classifier__max_iter=149, classifier__max_leaf_nodes=18, classifier__min_samples_leaf=6; total time=   3.8s
# [CV] END classifier__learning_rate=0.09077961615333649, classifier__max_iter=153, classifier__max_leaf_nodes=18, classifier__min_samples_leaf=26; total time=   3.9s
# [CV] END classifier__learning_rate=0.09077961615333649, classifier__max_iter=153, classifier__max_leaf_nodes=18, classifier__min_samples_leaf=26; total time=   4.6s
# [CV] END classifier__learning_rate=0.09077961615333649, classifier__max_iter=153, classifier__max_leaf_nodes=18, classifier__min_samples_leaf=26; total time=   4.3s
# [CV] END classifier__learning_rate=0.09077961615333649, classifier__max_iter=153, classifier__max_leaf_nodes=18, classifier__min_samples_leaf=26; total time=   4.3s
# [CV] END classifier__learning_rate=0.09077961615333649, classifier__max_iter=153, classifier__max_leaf_nodes=18, classifier__min_samples_leaf=26; total time=   4.4s
# [CV] END classifier__learning_rate=0.01594952556655613, classifier__max_iter=501, classifier__max_leaf_nodes=40, classifier__min_samples_leaf=16; total time=   4.2s
# [CV] END classifier__learning_rate=0.01594952556655613, classifier__max_iter=501, classifier__max_leaf_nodes=40, classifier__min_samples_leaf=16; total time=   4.3s
# [CV] END classifier__learning_rate=0.01594952556655613, classifier__max_iter=501, classifier__max_leaf_nodes=40, classifier__min_samples_leaf=16; total time=   4.5s
# [CV] END classifier__learning_rate=0.01594952556655613, classifier__max_iter=501, classifier__max_leaf_nodes=40, classifier__min_samples_leaf=16; total time=   4.7s
# [CV] END classifier__learning_rate=0.01594952556655613, classifier__max_iter=501, classifier__max_leaf_nodes=40, classifier__min_samples_leaf=16; total time=   4.6s
# [CV] END classifier__learning_rate=0.18850479889719593, classifier__max_iter=545, classifier__max_leaf_nodes=28, classifier__min_samples_leaf=20; total time=   4.5s
# [CV] END classifier__learning_rate=0.18850479889719593, classifier__max_iter=545, classifier__max_leaf_nodes=28, classifier__min_samples_leaf=20; total time=   4.1s
# [CV] END classifier__learning_rate=0.18850479889719593, classifier__max_iter=545, classifier__max_leaf_nodes=28, classifier__min_samples_leaf=20; total time=   4.3s
# [CV] END classifier__learning_rate=0.18850479889719593, classifier__max_iter=545, classifier__max_leaf_nodes=28, classifier__min_samples_leaf=20; total time=   4.2s
# [CV] END classifier__learning_rate=0.07204274607310872, classifier__max_iter=561, classifier__max_leaf_nodes=37, classifier__min_samples_leaf=29; total time=   4.2s
# [CV] END classifier__learning_rate=0.18850479889719593, classifier__max_iter=545, classifier__max_leaf_nodes=28, classifier__min_samples_leaf=20; total time=   4.4s
# [CV] END classifier__learning_rate=0.07204274607310872, classifier__max_iter=561, classifier__max_leaf_nodes=37, classifier__min_samples_leaf=29; total time=   4.5s
# [CV] END classifier__learning_rate=0.07204274607310872, classifier__max_iter=561, classifier__max_leaf_nodes=37, classifier__min_samples_leaf=29; total time=   4.4s
# [CV] END classifier__learning_rate=0.07204274607310872, classifier__max_iter=561, classifier__max_leaf_nodes=37, classifier__min_samples_leaf=29; total time=   4.9s
# [CV] END classifier__learning_rate=0.07204274607310872, classifier__max_iter=561, classifier__max_leaf_nodes=37, classifier__min_samples_leaf=29; total time=   4.8s
# [CV] END classifier__learning_rate=0.19262268462637636, classifier__max_iter=312, classifier__max_leaf_nodes=30, classifier__min_samples_leaf=17; total time=   4.1s
# [CV] END classifier__learning_rate=0.19262268462637636, classifier__max_iter=312, classifier__max_leaf_nodes=30, classifier__min_samples_leaf=17; total time=   4.5s
# [CV] END classifier__learning_rate=0.19262268462637636, classifier__max_iter=312, classifier__max_leaf_nodes=30, classifier__min_samples_leaf=17; total time=   5.4s
# [CV] END classifier__learning_rate=0.19262268462637636, classifier__max_iter=312, classifier__max_leaf_nodes=30, classifier__min_samples_leaf=17; total time=   5.0s
# [CV] END classifier__learning_rate=0.19262268462637636, classifier__max_iter=312, classifier__max_leaf_nodes=30, classifier__min_samples_leaf=17; total time=   5.7s
# [CV] END classifier__learning_rate=0.061556316037040225, classifier__max_iter=152, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=29; total time=   5.2s
# [CV] END classifier__learning_rate=0.061556316037040225, classifier__max_iter=152, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=29; total time=   6.4s
# [CV] END classifier__learning_rate=0.061556316037040225, classifier__max_iter=152, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=29; total time=   6.0s
# [CV] END classifier__learning_rate=0.061556316037040225, classifier__max_iter=152, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=29; total time=   6.1s
# [CV] END classifier__learning_rate=0.061556316037040225, classifier__max_iter=152, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=29; total time=   6.5s
# [CV] END classifier__learning_rate=0.06337755684060234, classifier__max_iter=479, classifier__max_leaf_nodes=43, classifier__min_samples_leaf=19; total time=   6.1s
# [CV] END classifier__learning_rate=0.06337755684060234, classifier__max_iter=479, classifier__max_leaf_nodes=43, classifier__min_samples_leaf=19; total time=   7.5s
# [CV] END classifier__learning_rate=0.06337755684060234, classifier__max_iter=479, classifier__max_leaf_nodes=43, classifier__min_samples_leaf=19; total time=   6.0s
# [CV] END classifier__learning_rate=0.041400718421970475, classifier__max_iter=444, classifier__max_leaf_nodes=21, classifier__min_samples_leaf=13; total time=   5.5s
# [CV] END classifier__learning_rate=0.06337755684060234, classifier__max_iter=479, classifier__max_leaf_nodes=43, classifier__min_samples_leaf=19; total time=   6.1s
# [CV] END classifier__learning_rate=0.06337755684060234, classifier__max_iter=479, classifier__max_leaf_nodes=43, classifier__min_samples_leaf=19; total time=   6.1s
# [CV] END classifier__learning_rate=0.041400718421970475, classifier__max_iter=444, classifier__max_leaf_nodes=21, classifier__min_samples_leaf=13; total time=   5.9s
# [CV] END classifier__learning_rate=0.041400718421970475, classifier__max_iter=444, classifier__max_leaf_nodes=21, classifier__min_samples_leaf=13; total time=   5.4s
# [CV] END classifier__learning_rate=0.041400718421970475, classifier__max_iter=444, classifier__max_leaf_nodes=21, classifier__min_samples_leaf=13; total time=   5.3s
# [CV] END classifier__learning_rate=0.041400718421970475, classifier__max_iter=444, classifier__max_leaf_nodes=21, classifier__min_samples_leaf=13; total time=   6.0s
# [CV] END classifier__learning_rate=0.1567265061663649, classifier__max_iter=591, classifier__max_leaf_nodes=22, classifier__min_samples_leaf=28; total time=   5.7s
# [CV] END classifier__learning_rate=0.1567265061663649, classifier__max_iter=591, classifier__max_leaf_nodes=22, classifier__min_samples_leaf=28; total time=   5.2s
# [CV] END classifier__learning_rate=0.1567265061663649, classifier__max_iter=591, classifier__max_leaf_nodes=22, classifier__min_samples_leaf=28; total time=   4.7s
# [CV] END classifier__learning_rate=0.012675166315866047, classifier__max_iter=598, classifier__max_leaf_nodes=31, classifier__min_samples_leaf=12; total time=   4.6s
# [CV] END classifier__learning_rate=0.1567265061663649, classifier__max_iter=591, classifier__max_leaf_nodes=22, classifier__min_samples_leaf=28; total time=   5.0s
# [CV] END classifier__learning_rate=0.1567265061663649, classifier__max_iter=591, classifier__max_leaf_nodes=22, classifier__min_samples_leaf=28; total time=   5.1s
# [CV] END classifier__learning_rate=0.012675166315866047, classifier__max_iter=598, classifier__max_leaf_nodes=31, classifier__min_samples_leaf=12; total time=   4.7s
# [CV] END classifier__learning_rate=0.012675166315866047, classifier__max_iter=598, classifier__max_leaf_nodes=31, classifier__min_samples_leaf=12; total time=   4.8s
# [CV] END classifier__learning_rate=0.012675166315866047, classifier__max_iter=598, classifier__max_leaf_nodes=31, classifier__min_samples_leaf=12; total time=   4.9s
# [CV] END classifier__learning_rate=0.1485113619277876, classifier__max_iter=388, classifier__max_leaf_nodes=19, classifier__min_samples_leaf=14; total time=   4.4s
# [CV] END classifier__learning_rate=0.012675166315866047, classifier__max_iter=598, classifier__max_leaf_nodes=31, classifier__min_samples_leaf=12; total time=   5.0s
# [CV] END classifier__learning_rate=0.1485113619277876, classifier__max_iter=388, classifier__max_leaf_nodes=19, classifier__min_samples_leaf=14; total time=   4.2s
# [CV] END classifier__learning_rate=0.1485113619277876, classifier__max_iter=388, classifier__max_leaf_nodes=19, classifier__min_samples_leaf=14; total time=   4.5s
# [CV] END classifier__learning_rate=0.1485113619277876, classifier__max_iter=388, classifier__max_leaf_nodes=19, classifier__min_samples_leaf=14; total time=   4.8s
# [CV] END classifier__learning_rate=0.1485113619277876, classifier__max_iter=388, classifier__max_leaf_nodes=19, classifier__min_samples_leaf=14; total time=   5.3s
# [CV] END classifier__learning_rate=0.0781084884234118, classifier__max_iter=140, classifier__max_leaf_nodes=42, classifier__min_samples_leaf=11; total time=   4.6s
# [CV] END classifier__learning_rate=0.0781084884234118, classifier__max_iter=140, classifier__max_leaf_nodes=42, classifier__min_samples_leaf=11; total time=   5.0s
# [CV] END classifier__learning_rate=0.0781084884234118, classifier__max_iter=140, classifier__max_leaf_nodes=42, classifier__min_samples_leaf=11; total time=   4.8s
# [CV] END classifier__learning_rate=0.0781084884234118, classifier__max_iter=140, classifier__max_leaf_nodes=42, classifier__min_samples_leaf=11; total time=   4.8s
# [CV] END classifier__learning_rate=0.0781084884234118, classifier__max_iter=140, classifier__max_leaf_nodes=42, classifier__min_samples_leaf=11; total time=   4.8s
# [CV] END classifier__learning_rate=0.1715073297800619, classifier__max_iter=367, classifier__max_leaf_nodes=48, classifier__min_samples_leaf=5; total time=   4.8s
# [CV] END classifier__learning_rate=0.1715073297800619, classifier__max_iter=367, classifier__max_leaf_nodes=48, classifier__min_samples_leaf=5; total time=   4.0s
# [CV] END classifier__learning_rate=0.1715073297800619, classifier__max_iter=367, classifier__max_leaf_nodes=48, classifier__min_samples_leaf=5; total time=   4.3s
# [CV] END classifier__learning_rate=0.02207608655434449, classifier__max_iter=506, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=9; total time=   4.1s
# [CV] END classifier__learning_rate=0.02207608655434449, classifier__max_iter=506, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=9; total time=   4.0s
# [CV] END classifier__learning_rate=0.1715073297800619, classifier__max_iter=367, classifier__max_leaf_nodes=48, classifier__min_samples_leaf=5; total time=   4.3s
# [CV] END classifier__learning_rate=0.1715073297800619, classifier__max_iter=367, classifier__max_leaf_nodes=48, classifier__min_samples_leaf=5; total time=   4.5s
# [CV] END classifier__learning_rate=0.02207608655434449, classifier__max_iter=506, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=9; total time=   4.1s
# [CV] END classifier__learning_rate=0.02207608655434449, classifier__max_iter=506, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=9; total time=   4.1s
# [CV] END classifier__learning_rate=0.02207608655434449, classifier__max_iter=506, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=9; total time=   4.5s
# [CV] END classifier__learning_rate=0.1486251738842322, classifier__max_iter=459, classifier__max_leaf_nodes=36, classifier__min_samples_leaf=7; total time=   4.3s
# [CV] END classifier__learning_rate=0.1486251738842322, classifier__max_iter=459, classifier__max_leaf_nodes=36, classifier__min_samples_leaf=7; total time=   4.5s
# [CV] END classifier__learning_rate=0.1486251738842322, classifier__max_iter=459, classifier__max_leaf_nodes=36, classifier__min_samples_leaf=7; total time=   4.6s
# [CV] END classifier__learning_rate=0.1486251738842322, classifier__max_iter=459, classifier__max_leaf_nodes=36, classifier__min_samples_leaf=7; total time=   5.1s
# [CV] END classifier__learning_rate=0.09972083578077036, classifier__max_iter=200, classifier__max_leaf_nodes=28, classifier__min_samples_leaf=7; total time=   5.2s
# [CV] END classifier__learning_rate=0.1486251738842322, classifier__max_iter=459, classifier__max_leaf_nodes=36, classifier__min_samples_leaf=7; total time=   5.3s
# [CV] END classifier__learning_rate=0.09972083578077036, classifier__max_iter=200, classifier__max_leaf_nodes=28, classifier__min_samples_leaf=7; total time=   4.6s
# [CV] END classifier__learning_rate=0.09972083578077036, classifier__max_iter=200, classifier__max_leaf_nodes=28, classifier__min_samples_leaf=7; total time=   5.1s
# [CV] END classifier__learning_rate=0.09972083578077036, classifier__max_iter=200, classifier__max_leaf_nodes=28, classifier__min_samples_leaf=7; total time=   4.9s
# [CV] END classifier__learning_rate=0.15454915923721052, classifier__max_iter=317, classifier__max_leaf_nodes=28, classifier__min_samples_leaf=11; total time=   4.7s
# [CV] END classifier__learning_rate=0.09972083578077036, classifier__max_iter=200, classifier__max_leaf_nodes=28, classifier__min_samples_leaf=7; total time=   5.3s
# [CV] END classifier__learning_rate=0.15454915923721052, classifier__max_iter=317, classifier__max_leaf_nodes=28, classifier__min_samples_leaf=11; total time=   4.0s
# [CV] END classifier__learning_rate=0.15454915923721052, classifier__max_iter=317, classifier__max_leaf_nodes=28, classifier__min_samples_leaf=11; total time=   4.8s
# [CV] END classifier__learning_rate=0.15454915923721052, classifier__max_iter=317, classifier__max_leaf_nodes=28, classifier__min_samples_leaf=11; total time=   4.2s
# [CV] END classifier__learning_rate=0.017682382012301955, classifier__max_iter=306, classifier__max_leaf_nodes=29, classifier__min_samples_leaf=14; total time=   4.5s
# [CV] END classifier__learning_rate=0.15454915923721052, classifier__max_iter=317, classifier__max_leaf_nodes=28, classifier__min_samples_leaf=11; total time=   4.8s
# [CV] END classifier__learning_rate=0.017682382012301955, classifier__max_iter=306, classifier__max_leaf_nodes=29, classifier__min_samples_leaf=14; total time=   4.4s
# [CV] END classifier__learning_rate=0.017682382012301955, classifier__max_iter=306, classifier__max_leaf_nodes=29, classifier__min_samples_leaf=14; total time=   4.6s
# [CV] END classifier__learning_rate=0.017682382012301955, classifier__max_iter=306, classifier__max_leaf_nodes=29, classifier__min_samples_leaf=14; total time=   4.8s
# [CV] END classifier__learning_rate=0.017682382012301955, classifier__max_iter=306, classifier__max_leaf_nodes=29, classifier__min_samples_leaf=14; total time=   4.7s
# [CV] END classifier__learning_rate=0.09347393535449632, classifier__max_iter=278, classifier__max_leaf_nodes=46, classifier__min_samples_leaf=11; total time=   4.5s
# [CV] END classifier__learning_rate=0.09347393535449632, classifier__max_iter=278, classifier__max_leaf_nodes=46, classifier__min_samples_leaf=11; total time=   4.3s
# [CV] END classifier__learning_rate=0.09347393535449632, classifier__max_iter=278, classifier__max_leaf_nodes=46, classifier__min_samples_leaf=11; total time=   4.5s
# [CV] END classifier__learning_rate=0.09347393535449632, classifier__max_iter=278, classifier__max_leaf_nodes=46, classifier__min_samples_leaf=11; total time=   4.5s
# [CV] END classifier__learning_rate=0.09347393535449632, classifier__max_iter=278, classifier__max_leaf_nodes=46, classifier__min_samples_leaf=11; total time=   4.2s
# [CV] END classifier__learning_rate=0.10032034240460123, classifier__max_iter=195, classifier__max_leaf_nodes=18, classifier__min_samples_leaf=9; total time=   4.2s
# [CV] END classifier__learning_rate=0.10032034240460123, classifier__max_iter=195, classifier__max_leaf_nodes=18, classifier__min_samples_leaf=9; total time=   4.1s
# [CV] END classifier__learning_rate=0.10032034240460123, classifier__max_iter=195, classifier__max_leaf_nodes=18, classifier__min_samples_leaf=9; total time=   3.9s
# [CV] END classifier__learning_rate=0.10032034240460123, classifier__max_iter=195, classifier__max_leaf_nodes=18, classifier__min_samples_leaf=9; total time=   3.8s
# [CV] END classifier__learning_rate=0.10032034240460123, classifier__max_iter=195, classifier__max_leaf_nodes=18, classifier__min_samples_leaf=9; total time=   3.8s
# [CV] END classifier__learning_rate=0.057365523538286244, classifier__max_iter=336, classifier__max_leaf_nodes=29, classifier__min_samples_leaf=15; total time=   4.0s
# [CV] END classifier__learning_rate=0.057365523538286244, classifier__max_iter=336, classifier__max_leaf_nodes=29, classifier__min_samples_leaf=15; total time=   4.2s
# [CV] END classifier__learning_rate=0.057365523538286244, classifier__max_iter=336, classifier__max_leaf_nodes=29, classifier__min_samples_leaf=15; total time=   3.8s
# [CV] END classifier__learning_rate=0.057365523538286244, classifier__max_iter=336, classifier__max_leaf_nodes=29, classifier__min_samples_leaf=15; total time=   3.6s
# [CV] END classifier__learning_rate=0.057365523538286244, classifier__max_iter=336, classifier__max_leaf_nodes=29, classifier__min_samples_leaf=15; total time=   4.1s
# [CV] END classifier__learning_rate=0.048581632699606185, classifier__max_iter=112, classifier__max_leaf_nodes=46, classifier__min_samples_leaf=11; total time=   3.7s
# [CV] END classifier__learning_rate=0.048581632699606185, classifier__max_iter=112, classifier__max_leaf_nodes=46, classifier__min_samples_leaf=11; total time=   4.1s
# [CV] END classifier__learning_rate=0.048581632699606185, classifier__max_iter=112, classifier__max_leaf_nodes=46, classifier__min_samples_leaf=11; total time=   4.0s
# [CV] END classifier__learning_rate=0.048581632699606185, classifier__max_iter=112, classifier__max_leaf_nodes=46, classifier__min_samples_leaf=11; total time=   3.9s
# [CV] END classifier__learning_rate=0.048581632699606185, classifier__max_iter=112, classifier__max_leaf_nodes=46, classifier__min_samples_leaf=11; total time=   4.0s
# [CV] END classifier__learning_rate=0.06505277605361592, classifier__max_iter=185, classifier__max_leaf_nodes=42, classifier__min_samples_leaf=6; total time=   4.0s
# [CV] END classifier__learning_rate=0.06505277605361592, classifier__max_iter=185, classifier__max_leaf_nodes=42, classifier__min_samples_leaf=6; total time=   4.2s
# [CV] END classifier__learning_rate=0.06505277605361592, classifier__max_iter=185, classifier__max_leaf_nodes=42, classifier__min_samples_leaf=6; total time=   3.7s
# [CV] END classifier__learning_rate=0.06505277605361592, classifier__max_iter=185, classifier__max_leaf_nodes=42, classifier__min_samples_leaf=6; total time=   3.8s
# [CV] END classifier__learning_rate=0.06505277605361592, classifier__max_iter=185, classifier__max_leaf_nodes=42, classifier__min_samples_leaf=6; total time=   3.9s
# [CV] END classifier__learning_rate=0.12862726914542072, classifier__max_iter=161, classifier__max_leaf_nodes=20, classifier__min_samples_leaf=16; total time=   3.9s
# [CV] END classifier__learning_rate=0.12862726914542072, classifier__max_iter=161, classifier__max_leaf_nodes=20, classifier__min_samples_leaf=16; total time=   4.1s
# [CV] END classifier__learning_rate=0.12862726914542072, classifier__max_iter=161, classifier__max_leaf_nodes=20, classifier__min_samples_leaf=16; total time=   4.0s
# [CV] END classifier__learning_rate=0.12862726914542072, classifier__max_iter=161, classifier__max_leaf_nodes=20, classifier__min_samples_leaf=16; total time=   3.9s
# [CV] END classifier__learning_rate=0.12862726914542072, classifier__max_iter=161, classifier__max_leaf_nodes=20, classifier__min_samples_leaf=16; total time=   4.0s
# [CV] END classifier__learning_rate=0.04544831118834681, classifier__max_iter=385, classifier__max_leaf_nodes=25, classifier__min_samples_leaf=27; total time=   4.2s
# [CV] END classifier__learning_rate=0.04544831118834681, classifier__max_iter=385, classifier__max_leaf_nodes=25, classifier__min_samples_leaf=27; total time=   3.8s
# [CV] END classifier__learning_rate=0.04544831118834681, classifier__max_iter=385, classifier__max_leaf_nodes=25, classifier__min_samples_leaf=27; total time=   3.8s
# [CV] END classifier__learning_rate=0.04544831118834681, classifier__max_iter=385, classifier__max_leaf_nodes=25, classifier__min_samples_leaf=27; total time=   3.4s
# [CV] END classifier__learning_rate=0.04544831118834681, classifier__max_iter=385, classifier__max_leaf_nodes=25, classifier__min_samples_leaf=27; total time=   3.3s
# [CV] END classifier__learning_rate=0.18025734698546372, classifier__max_iter=330, classifier__max_leaf_nodes=47, classifier__min_samples_leaf=5; total time=   3.2s
# [CV] END classifier__learning_rate=0.18025734698546372, classifier__max_iter=330, classifier__max_leaf_nodes=47, classifier__min_samples_leaf=5; total time=   3.0s
# [CV] END classifier__learning_rate=0.18025734698546372, classifier__max_iter=330, classifier__max_leaf_nodes=47, classifier__min_samples_leaf=5; total time=   2.9s
# [CV] END classifier__learning_rate=0.18025734698546372, classifier__max_iter=330, classifier__max_leaf_nodes=47, classifier__min_samples_leaf=5; total time=   2.9s
# [CV] END classifier__learning_rate=0.18025734698546372, classifier__max_iter=330, classifier__max_leaf_nodes=47, classifier__min_samples_leaf=5; total time=   2.7s
# Best Parameters: {'classifier__learning_rate': np.float64(0.19262268462637636), 'classifier__max_iter': 312, 'classifier__max_leaf_nodes': 30, 'classifier__min_samples_leaf': 17}
# Best Score (Recall at FPR 0.1%): 0.7131450827653358

# %%
# Set the best parameters for the model

best_model = random_search.best_estimator_


best_model.fit(X_train, y_train)

oof_proba = cross_val_predict(best_model, X_train, y_train, cv=skf, method="predict_proba")[:, 1]
chosen_thr, strategy, metrics = choose_threshold_max_recall_at_fpr(
    y_true=y_train,
    proba=oof_proba,
    max_fpr=0.001
)

print(f"Chosen threshold after hyperparameter tuning: {chosen_thr}, strategy: {strategy}")
print("Metrics at chosen threshold after hyperparameter tuning:")
for metric_name, metric_value in metrics.items():
    print(f"{metric_name}: {round(metric_value, 4)}")
# Out:
# Chosen threshold after hyperparameter tuning: 0.6891431307667594, strategy: Max recall with FPR≤0.0010
# Metrics at chosen threshold after hyperparameter tuning:
# threshold: 0.6891
# fpr: 0.0009
# recall: 0.8299
# precision: 0.6181
# f1: 0.7086
