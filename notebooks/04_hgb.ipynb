# %%
import pandas as pd
import joblib
from pathlib import Path
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve

RANDOM_STATE = 42
TARGET_COL = "Class"
TEST_SIZE = 0.2

# %%
PROJECT_ROOT = Path("..").resolve()
DATA_RAW = PROJECT_ROOT / "data" / "raw"
SPLITS_DIR = PROJECT_ROOT / "data" / "splits"
REPORTS_DIR = PROJECT_ROOT / "reports"
MODELS_DIR = PROJECT_ROOT / "models"

# Ensure the directory exists
DATA_RAW.mkdir(parents=True, exist_ok=True)
SPLITS_DIR.mkdir(parents=True, exist_ok=True)
REPORTS_DIR.mkdir(parents=True, exist_ok=True)
MODELS_DIR.mkdir(parents=True, exist_ok=True)

# Check if the file exists before reading
csv_file = DATA_RAW / "creditcard.csv"
if csv_file.exists():
    df = pd.read_csv(csv_file, low_memory=False)  # Suppress DtypeWarning
    df.head(10)
else:
    print(f"File not found: {csv_file}")

# %%
X = df.drop(columns=[TARGET_COL])
y = df[TARGET_COL]

# %%
train_idx = pd.read_csv(SPLITS_DIR / "X_train.csv", header=None).squeeze()

X_train = X.loc[train_idx].copy()
y_train = y.loc[train_idx].copy()

# %%
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, FunctionTransformer
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.ensemble import HistGradientBoostingClassifier

v_columns = [f"V{i}" for i in range(1, 29)]
amount_col = ["Amount"]
time_col = ["Time"]

SECONDS_IN_DAY = 86400

def time_cyc_features(X):
    t = (X % SECONDS_IN_DAY) / SECONDS_IN_DAY
    return np.hstack([np.sin(2 * np.pi * t), np.cos(2 * np.pi * t)])

def coerce_numeric_df(X):
    X = X.copy()
    for c in X.columns:
        X[c] = pd.to_numeric(X[c], errors="coerce")
    return X

to_numeric = FunctionTransformer(coerce_numeric_df, validate=False)

amount_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("log1p", FunctionTransformer(np.log1p, validate=True)),
    ("scaler", StandardScaler()),
])

v_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler()),
])

time_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("cyc", FunctionTransformer(time_cyc_features, validate=True)),
    ("scaler", StandardScaler()),
])

preprocessor = ColumnTransformer(
    transformers=[
        ("amount", amount_transformer, amount_col),
        ("time", time_transformer, time_col),
        ("v", v_transformer, v_columns),
    ],
    remainder="drop"
)

model = Pipeline(steps=[
    ("to_numeric", to_numeric),
    ("preprocessor", preprocessor),
    ("classifier", HistGradientBoostingClassifier(random_state=RANDOM_STATE
    ))
])

model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('to_numeric',
#                  FunctionTransformer(func=<function coerce_numeric_df at 0x118d67060>)),
#                 ('preprocessor',
#                  ColumnTransformer(transformers=[('amount',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('log1p',
#                                                                    FunctionTransformer(func=<ufunc 'log1p'>,
#                                                                                        validate=True)),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Amount']),
#                                                  ('time',
#                                                   Pipeline(steps=[('...
#                                                                    StandardScaler())]),
#                                                   ['Time']),
#                                                  ('v',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['V1', 'V2', 'V3', 'V4', 'V5',
#                                                    'V6', 'V7', 'V8', 'V9',
#                                                    'V10', 'V11', 'V12', 'V13',
#                                                    'V14', 'V15', 'V16', 'V17',
#                                                    'V18', 'V19', 'V20', 'V21',
#                                                    'V22', 'V23', 'V24', 'V25',
#                                                    'V26', 'V27', 'V28'])])),
#                 ('classifier',
#                  HistGradientBoostingClassifier(random_state=42))])

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_predict

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)

y_pred = cross_val_predict(model, X_train, y_train, cv=skf)

oof_proba = cross_val_predict(model, X_train, y_train, cv=skf, method="predict_proba")[:, 1]

# %%
precision, recall, thresholds = precision_recall_curve(y_train, oof_proba)
thr_ext = np.r_[0.0, thresholds]
print(len(precision), len(recall), len(thr_ext))
# Out:
# 6320 6320 6320

# %%
import sys
from pathlib import Path

# Add the parent directory of 'src' to sys.path
sys.path.append(str(PROJECT_ROOT))

from src.choose_thresholds import choose_threshold_max_recall_at_fpr

chosen_thr, strategy, metrics = choose_threshold_max_recall_at_fpr(
    y_true=y_train,
    proba=oof_proba,
    max_fpr=0.001
)

print(f"Chosen threshold: {chosen_thr}, strategy: {strategy}")
print("Metrics at chosen threshold:")
for metric_name, metric_value in metrics.items():
    print(f"{metric_name}: {round(metric_value, 4)}")
# Out:
# Chosen threshold: 0.603880655997441, strategy: Max recall with FPR≤0.0010
# Metrics at chosen threshold:
# threshold: 0.6039
# fpr: 0.0009
# recall: 0.7005
# precision: 0.586
# f1: 0.6382

# %%
cm = confusion_matrix(y_train, (oof_proba >= chosen_thr).astype(int))
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[227256    195]
#  [   118    276]]

# %%
#PR curve for chosen threshold

plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label="Precision-Recall Curve")
plt.scatter(metrics['recall'], metrics['precision'], color='red', label='Chosen Threshold', zorder=5)
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve with Chosen Threshold (HGB)")
plt.legend()
plt.grid()
plt.savefig(REPORTS_DIR / "pr_curve_chosen_threshold_hgb.png")
plt.show()

#Recall@FixedPRecision graph

plt.figure(figsize=(8, 6))
plt.plot(thr_ext, recall, label="Recall vs Threshold")
plt.scatter(chosen_thr, metrics['recall'], color='red', label='Chosen Threshold', zorder=5)
plt.xlabel("Threshold")
plt.ylabel("Recall")
plt.title("Recall vs Threshold with Chosen Threshold (HGB)")
plt.legend()
plt.grid()
plt.savefig(REPORTS_DIR / "recall_vs_threshold_chosen_threshold_hgb.png")

# %%
import numpy as np
from scipy.stats import uniform, randint

from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import roc_curve
from sklearn.metrics import make_scorer
from sklearn.utils.class_weight import compute_sample_weight

# --- 1) Param search space (HGB) ---
param_distributions = {
    "classifier__learning_rate": uniform(0.01, 0.19),
    "classifier__max_leaf_nodes": randint(15, 50),
    "classifier__min_samples_leaf": randint(5, 30),
    "classifier__max_iter": randint(100, 600),
    "classifier__max_depth": randint(3, 15),
    "classifier__l2_regularization": uniform(0.0, 1.0),
    "classifier__max_bins": randint(100, 255),
}

# --- 2) Custom scorer: maximize recall (TPR) subject to FPR <= max_fpr ---
def recall_at_max_fpr(y_true, y_score, max_fpr=0.001, **kwargs):
    """
    y_score is expected to be probability of positive class (fraud).
    **kwargs is required because newer sklearn may pass extra kwargs (e.g., needs_proba).
    """
    fpr, tpr, _ = roc_curve(y_true, y_score)
    ok = np.where(fpr <= max_fpr)[0]
    return float(np.max(tpr[ok])) if ok.size else 0.0

recall_fpr_0p1_scorer = make_scorer(
    recall_at_max_fpr,
    needs_proba=True,   # tells sklearn to pass predict_proba output
    max_fpr=0.001       # passed to recall_at_max_fpr as kwarg
)

# --- 3) Multi-metric scoring; refit by your KPI ---
scoring = {
    "roc_auc": "roc_auc",
    "pr_auc": "average_precision",
    "recall_fpr_0p1": recall_fpr_0p1_scorer,
}

random_search = RandomizedSearchCV(
    estimator=model,
    param_distributions=param_distributions,
    n_iter=40,
    scoring=scoring,
    refit="recall_fpr_0p1",
    n_jobs=-1,
    cv=skf,
    random_state=RANDOM_STATE,
    verbose=2,
    error_score="raise",  # fail fast if something else breaks
)

# --- 4) Compute sample weights for class balancing ---
sample_weight = compute_sample_weight(class_weight="balanced", y=y_train)

random_search.fit(X_train, y_train, classifier__sample_weight=sample_weight)

print("Best Parameters:", random_search.best_params_)
print("Best Cross-Validation Recall@FPR=0.1%:", random_search.best_score_)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV] END classifier__l2_regularization=0.3745401188473625, classifier__learning_rate=0.19063571821788408, classifier__max_bins=206, classifier__max_depth=10, classifier__max_iter=288, classifier__max_leaf_nodes=35, classifier__min_samples_leaf=11; total time=   4.3s
# [CV] END classifier__l2_regularization=0.3745401188473625, classifier__learning_rate=0.19063571821788408, classifier__max_bins=206, classifier__max_depth=10, classifier__max_iter=288, classifier__max_leaf_nodes=35, classifier__min_samples_leaf=11; total time=   4.4s
# [CV] END classifier__l2_regularization=0.3745401188473625, classifier__learning_rate=0.19063571821788408, classifier__max_bins=206, classifier__max_depth=10, classifier__max_iter=288, classifier__max_leaf_nodes=35, classifier__min_samples_leaf=11; total time=   4.8s
# [CV] END classifier__l2_regularization=0.3745401188473625, classifier__learning_rate=0.19063571821788408, classifier__max_bins=206, classifier__max_depth=10, classifier__max_iter=288, classifier__max_leaf_nodes=35, classifier__min_samples_leaf=11; total time=   4.9s
# [CV] END classifier__l2_regularization=0.3745401188473625, classifier__learning_rate=0.19063571821788408, classifier__max_bins=206, classifier__max_depth=10, classifier__max_iter=288, classifier__max_leaf_nodes=35, classifier__min_samples_leaf=11; total time=   5.0s
# [CV] END classifier__l2_regularization=0.44583275285359114, classifier__learning_rate=0.028995234005420548, classifier__max_bins=187, classifier__max_depth=7, classifier__max_iter=199, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=7; total time=   6.0s
# [CV] END classifier__l2_regularization=0.44583275285359114, classifier__learning_rate=0.028995234005420548, classifier__max_bins=187, classifier__max_depth=7, classifier__max_iter=199, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=7; total time=   6.0s
# [CV] END classifier__l2_regularization=0.44583275285359114, classifier__learning_rate=0.028995234005420548, classifier__max_bins=187, classifier__max_depth=7, classifier__max_iter=199, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=7; total time=   6.7s
# [CV] END classifier__l2_regularization=0.44583275285359114, classifier__learning_rate=0.028995234005420548, classifier__max_bins=187, classifier__max_depth=7, classifier__max_iter=199, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=7; total time=   6.9s
# [CV] END classifier__l2_regularization=0.44583275285359114, classifier__learning_rate=0.028995234005420548, classifier__max_bins=187, classifier__max_depth=7, classifier__max_iter=199, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=7; total time=   7.4s
# [CV] END classifier__l2_regularization=0.020584494295802447, classifier__learning_rate=0.19428287191077892, classifier__max_bins=137, classifier__max_depth=4, classifier__max_iter=291, classifier__max_leaf_nodes=35, classifier__min_samples_leaf=5; total time=   3.4s
# [CV] END classifier__l2_regularization=0.020584494295802447, classifier__learning_rate=0.19428287191077892, classifier__max_bins=137, classifier__max_depth=4, classifier__max_iter=291, classifier__max_leaf_nodes=35, classifier__min_samples_leaf=5; total time=   3.3s
# [CV] END classifier__l2_regularization=0.020584494295802447, classifier__learning_rate=0.19428287191077892, classifier__max_bins=137, classifier__max_depth=4, classifier__max_iter=291, classifier__max_leaf_nodes=35, classifier__min_samples_leaf=5; total time=   3.2s
# [CV] END classifier__l2_regularization=0.020584494295802447, classifier__learning_rate=0.19428287191077892, classifier__max_bins=137, classifier__max_depth=4, classifier__max_iter=291, classifier__max_leaf_nodes=35, classifier__min_samples_leaf=5; total time=   3.2s
# [CV] END classifier__l2_regularization=0.020584494295802447, classifier__learning_rate=0.19428287191077892, classifier__max_bins=137, classifier__max_depth=4, classifier__max_iter=291, classifier__max_leaf_nodes=35, classifier__min_samples_leaf=5; total time=   3.2s
# [CV] END classifier__l2_regularization=0.3042422429595377, classifier__learning_rate=0.10970372201012518, classifier__max_bins=188, classifier__max_depth=3, classifier__max_iter=574, classifier__max_leaf_nodes=42, classifier__min_samples_leaf=20; total time=   3.5s
# [CV] END classifier__l2_regularization=0.3042422429595377, classifier__learning_rate=0.10970372201012518, classifier__max_bins=188, classifier__max_depth=3, classifier__max_iter=574, classifier__max_leaf_nodes=42, classifier__min_samples_leaf=20; total time=   3.2s
# [CV] END classifier__l2_regularization=0.3042422429595377, classifier__learning_rate=0.10970372201012518, classifier__max_bins=188, classifier__max_depth=3, classifier__max_iter=574, classifier__max_leaf_nodes=42, classifier__min_samples_leaf=20; total time=   3.4s
# /Users/uvlazhnitel/Documents/coding/DataScience/Credit-Card-Fraud/.venv/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END classifier__l2_regularization=0.3042422429595377, classifier__learning_rate=0.10970372201012518, classifier__max_bins=188, classifier__max_depth=3, classifier__max_iter=574, classifier__max_leaf_nodes=42, classifier__min_samples_leaf=20; total time=   3.4s
# [CV] END classifier__l2_regularization=0.3042422429595377, classifier__learning_rate=0.10970372201012518, classifier__max_bins=188, classifier__max_depth=3, classifier__max_iter=574, classifier__max_leaf_nodes=42, classifier__min_samples_leaf=20; total time=   3.2s
# [CV] END classifier__l2_regularization=0.23277134043030423, classifier__learning_rate=0.02721522256123595, classifier__max_bins=150, classifier__max_depth=14, classifier__max_iter=154, classifier__max_leaf_nodes=17, classifier__min_samples_leaf=9; total time=   4.7s
# [CV] END classifier__l2_regularization=0.23277134043030423, classifier__learning_rate=0.02721522256123595, classifier__max_bins=150, classifier__max_depth=14, classifier__max_iter=154, classifier__max_leaf_nodes=17, classifier__min_samples_leaf=9; total time=   4.4s
# [CV] END classifier__l2_regularization=0.23277134043030423, classifier__learning_rate=0.02721522256123595, classifier__max_bins=150, classifier__max_depth=14, classifier__max_iter=154, classifier__max_leaf_nodes=17, classifier__min_samples_leaf=9; total time=   4.9s
# [CV] END classifier__l2_regularization=0.23277134043030423, classifier__learning_rate=0.02721522256123595, classifier__max_bins=150, classifier__max_depth=14, classifier__max_iter=154, classifier__max_leaf_nodes=17, classifier__min_samples_leaf=9; total time=   4.6s
# [CV] END classifier__l2_regularization=0.23277134043030423, classifier__learning_rate=0.02721522256123595, classifier__max_bins=150, classifier__max_depth=14, classifier__max_iter=154, classifier__max_leaf_nodes=17, classifier__min_samples_leaf=9; total time=   4.8s
# [CV] END classifier__l2_regularization=0.6075448519014384, classifier__learning_rate=0.04239958350058539, classifier__max_bins=117, classifier__max_depth=6, classifier__max_iter=188, classifier__max_leaf_nodes=28, classifier__min_samples_leaf=22; total time=   3.5s
# [CV] END classifier__l2_regularization=0.6075448519014384, classifier__learning_rate=0.04239958350058539, classifier__max_bins=117, classifier__max_depth=6, classifier__max_iter=188, classifier__max_leaf_nodes=28, classifier__min_samples_leaf=22; total time=   3.9s
# [CV] END classifier__l2_regularization=0.6075448519014384, classifier__learning_rate=0.04239958350058539, classifier__max_bins=117, classifier__max_depth=6, classifier__max_iter=188, classifier__max_leaf_nodes=28, classifier__min_samples_leaf=22; total time=   3.6s
# [CV] END classifier__l2_regularization=0.6075448519014384, classifier__learning_rate=0.04239958350058539, classifier__max_bins=117, classifier__max_depth=6, classifier__max_iter=188, classifier__max_leaf_nodes=28, classifier__min_samples_leaf=22; total time=   4.1s
# [CV] END classifier__l2_regularization=0.6075448519014384, classifier__learning_rate=0.04239958350058539, classifier__max_bins=117, classifier__max_depth=6, classifier__max_iter=188, classifier__max_leaf_nodes=28, classifier__min_samples_leaf=22; total time=   4.5s
# [CV] END classifier__l2_regularization=0.3854165025399161, classifier__learning_rate=0.013033587921840697, classifier__max_bins=229, classifier__max_depth=6, classifier__max_iter=191, classifier__max_leaf_nodes=21, classifier__min_samples_leaf=16; total time=   6.7s
# [CV] END classifier__l2_regularization=0.3854165025399161, classifier__learning_rate=0.013033587921840697, classifier__max_bins=229, classifier__max_depth=6, classifier__max_iter=191, classifier__max_leaf_nodes=21, classifier__min_samples_leaf=16; total time=   6.8s
# [CV] END classifier__l2_regularization=0.4951769101112702, classifier__learning_rate=0.016533819011891496, classifier__max_bins=180, classifier__max_depth=6, classifier__max_iter=149, classifier__max_leaf_nodes=18, classifier__min_samples_leaf=6; total time=   5.6s
# [CV] END classifier__l2_regularization=0.3854165025399161, classifier__learning_rate=0.013033587921840697, classifier__max_bins=229, classifier__max_depth=6, classifier__max_iter=191, classifier__max_leaf_nodes=21, classifier__min_samples_leaf=16; total time=   6.7s
# [CV] END classifier__l2_regularization=0.3854165025399161, classifier__learning_rate=0.013033587921840697, classifier__max_bins=229, classifier__max_depth=6, classifier__max_iter=191, classifier__max_leaf_nodes=21, classifier__min_samples_leaf=16; total time=   6.5s
# [CV] END classifier__l2_regularization=0.3854165025399161, classifier__learning_rate=0.013033587921840697, classifier__max_bins=229, classifier__max_depth=6, classifier__max_iter=191, classifier__max_leaf_nodes=21, classifier__min_samples_leaf=16; total time=   6.8s
# [CV] END classifier__l2_regularization=0.4951769101112702, classifier__learning_rate=0.016533819011891496, classifier__max_bins=180, classifier__max_depth=6, classifier__max_iter=149, classifier__max_leaf_nodes=18, classifier__min_samples_leaf=6; total time=   6.5s
# [CV] END classifier__l2_regularization=0.4951769101112702, classifier__learning_rate=0.016533819011891496, classifier__max_bins=180, classifier__max_depth=6, classifier__max_iter=149, classifier__max_leaf_nodes=18, classifier__min_samples_leaf=6; total time=   6.2s
# [CV] END classifier__l2_regularization=0.9394989415641891, classifier__learning_rate=0.18001719658125329, classifier__max_bins=113, classifier__max_depth=10, classifier__max_iter=561, classifier__max_leaf_nodes=37, classifier__min_samples_leaf=29; total time=   3.9s
# [CV] END classifier__l2_regularization=0.4251558744912447, classifier__learning_rate=0.04950891594495588, classifier__max_bins=103, classifier__max_depth=8, classifier__max_iter=576, classifier__max_leaf_nodes=32, classifier__min_samples_leaf=16; total time=   4.6s
# [CV] END classifier__l2_regularization=0.4951769101112702, classifier__learning_rate=0.016533819011891496, classifier__max_bins=180, classifier__max_depth=6, classifier__max_iter=149, classifier__max_leaf_nodes=18, classifier__min_samples_leaf=6; total time=   6.9s
# [CV] END classifier__l2_regularization=0.4251558744912447, classifier__learning_rate=0.04950891594495588, classifier__max_bins=103, classifier__max_depth=8, classifier__max_iter=576, classifier__max_leaf_nodes=32, classifier__min_samples_leaf=16; total time=   5.0s
# [CV] END classifier__l2_regularization=0.4251558744912447, classifier__learning_rate=0.04950891594495588, classifier__max_bins=103, classifier__max_depth=8, classifier__max_iter=576, classifier__max_leaf_nodes=32, classifier__min_samples_leaf=16; total time=   4.7s
# [CV] END classifier__l2_regularization=0.4951769101112702, classifier__learning_rate=0.016533819011891496, classifier__max_bins=180, classifier__max_depth=6, classifier__max_iter=149, classifier__max_leaf_nodes=18, classifier__min_samples_leaf=6; total time=   6.8s
# [CV] END classifier__l2_regularization=0.4251558744912447, classifier__learning_rate=0.04950891594495588, classifier__max_bins=103, classifier__max_depth=8, classifier__max_iter=576, classifier__max_leaf_nodes=32, classifier__min_samples_leaf=16; total time=   5.2s
# [CV] END classifier__l2_regularization=0.4251558744912447, classifier__learning_rate=0.04950891594495588, classifier__max_bins=103, classifier__max_depth=8, classifier__max_iter=576, classifier__max_leaf_nodes=32, classifier__min_samples_leaf=16; total time=   5.4s
# [CV] END classifier__l2_regularization=0.9394989415641891, classifier__learning_rate=0.18001719658125329, classifier__max_bins=113, classifier__max_depth=10, classifier__max_iter=561, classifier__max_leaf_nodes=37, classifier__min_samples_leaf=29; total time=   3.2s
# [CV] END classifier__l2_regularization=0.9394989415641891, classifier__learning_rate=0.18001719658125329, classifier__max_bins=113, classifier__max_depth=10, classifier__max_iter=561, classifier__max_leaf_nodes=37, classifier__min_samples_leaf=29; total time=   3.2s
# [CV] END classifier__l2_regularization=0.9394989415641891, classifier__learning_rate=0.18001719658125329, classifier__max_bins=113, classifier__max_depth=10, classifier__max_iter=561, classifier__max_leaf_nodes=37, classifier__min_samples_leaf=29; total time=   3.0s
# [CV] END classifier__l2_regularization=0.9394989415641891, classifier__learning_rate=0.18001719658125329, classifier__max_bins=113, classifier__max_depth=10, classifier__max_iter=561, classifier__max_leaf_nodes=37, classifier__min_samples_leaf=29; total time=   2.9s
# [CV] END classifier__l2_regularization=0.9611720243493491, classifier__learning_rate=0.17046143124884877, classifier__max_bins=181, classifier__max_depth=7, classifier__max_iter=379, classifier__max_leaf_nodes=40, classifier__min_samples_leaf=29; total time=   3.0s
# [CV] END classifier__l2_regularization=0.9611720243493491, classifier__learning_rate=0.17046143124884877, classifier__max_bins=181, classifier__max_depth=7, classifier__max_iter=379, classifier__max_leaf_nodes=40, classifier__min_samples_leaf=29; total time=   3.0s
# [CV] END classifier__l2_regularization=0.9611720243493491, classifier__learning_rate=0.17046143124884877, classifier__max_bins=181, classifier__max_depth=7, classifier__max_iter=379, classifier__max_leaf_nodes=40, classifier__min_samples_leaf=29; total time=   3.0s
# [CV] END classifier__l2_regularization=0.9611720243493491, classifier__learning_rate=0.17046143124884877, classifier__max_bins=181, classifier__max_depth=7, classifier__max_iter=379, classifier__max_leaf_nodes=40, classifier__min_samples_leaf=29; total time=   3.1s
# [CV] END classifier__l2_regularization=0.9611720243493491, classifier__learning_rate=0.17046143124884877, classifier__max_bins=181, classifier__max_depth=7, classifier__max_iter=379, classifier__max_leaf_nodes=40, classifier__min_samples_leaf=29; total time=   3.2s
# [CV] END classifier__l2_regularization=0.28093450968738076, classifier__learning_rate=0.1131122558000672, classifier__max_bins=140, classifier__max_depth=3, classifier__max_iter=444, classifier__max_leaf_nodes=21, classifier__min_samples_leaf=13; total time=   3.1s
# [CV] END classifier__l2_regularization=0.28093450968738076, classifier__learning_rate=0.1131122558000672, classifier__max_bins=140, classifier__max_depth=3, classifier__max_iter=444, classifier__max_leaf_nodes=21, classifier__min_samples_leaf=13; total time=   3.0s
# [CV] END classifier__l2_regularization=0.28093450968738076, classifier__learning_rate=0.1131122558000672, classifier__max_bins=140, classifier__max_depth=3, classifier__max_iter=444, classifier__max_leaf_nodes=21, classifier__min_samples_leaf=13; total time=   2.8s
# [CV] END classifier__l2_regularization=0.28093450968738076, classifier__learning_rate=0.1131122558000672, classifier__max_bins=140, classifier__max_depth=3, classifier__max_iter=444, classifier__max_leaf_nodes=21, classifier__min_samples_leaf=13; total time=   3.3s
# [CV] END classifier__l2_regularization=0.7722447692966574, classifier__learning_rate=0.04775597949149276, classifier__max_bins=162, classifier__max_depth=13, classifier__max_iter=598, classifier__max_leaf_nodes=31, classifier__min_samples_leaf=12; total time=   3.5s
# [CV] END classifier__l2_regularization=0.7722447692966574, classifier__learning_rate=0.04775597949149276, classifier__max_bins=162, classifier__max_depth=13, classifier__max_iter=598, classifier__max_leaf_nodes=31, classifier__min_samples_leaf=12; total time=   3.3s
# [CV] END classifier__l2_regularization=0.7290071680409873, classifier__learning_rate=0.1565413658703297, classifier__max_bins=104, classifier__max_depth=12, classifier__max_iter=330, classifier__max_leaf_nodes=42, classifier__min_samples_leaf=11; total time=   2.8s
# [CV] END classifier__l2_regularization=0.7722447692966574, classifier__learning_rate=0.04775597949149276, classifier__max_bins=162, classifier__max_depth=13, classifier__max_iter=598, classifier__max_leaf_nodes=31, classifier__min_samples_leaf=12; total time=   3.8s
# [CV] END classifier__l2_regularization=0.7722447692966574, classifier__learning_rate=0.04775597949149276, classifier__max_bins=162, classifier__max_depth=13, classifier__max_iter=598, classifier__max_leaf_nodes=31, classifier__min_samples_leaf=12; total time=   3.5s
# [CV] END classifier__l2_regularization=0.7722447692966574, classifier__learning_rate=0.04775597949149276, classifier__max_bins=162, classifier__max_depth=13, classifier__max_iter=598, classifier__max_leaf_nodes=31, classifier__min_samples_leaf=12; total time=   4.0s
# [CV] END classifier__l2_regularization=0.7290071680409873, classifier__learning_rate=0.1565413658703297, classifier__max_bins=104, classifier__max_depth=12, classifier__max_iter=330, classifier__max_leaf_nodes=42, classifier__min_samples_leaf=11; total time=   3.0s
# [CV] END classifier__l2_regularization=0.7290071680409873, classifier__learning_rate=0.1565413658703297, classifier__max_bins=104, classifier__max_depth=12, classifier__max_iter=330, classifier__max_leaf_nodes=42, classifier__min_samples_leaf=11; total time=   2.8s
# [CV] END classifier__l2_regularization=0.28093450968738076, classifier__learning_rate=0.1131122558000672, classifier__max_bins=140, classifier__max_depth=3, classifier__max_iter=444, classifier__max_leaf_nodes=21, classifier__min_samples_leaf=13; total time=   3.1s
# [CV] END classifier__l2_regularization=0.7290071680409873, classifier__learning_rate=0.1565413658703297, classifier__max_bins=104, classifier__max_depth=12, classifier__max_iter=330, classifier__max_leaf_nodes=42, classifier__min_samples_leaf=11; total time=   2.8s
# [CV] END classifier__l2_regularization=0.7290071680409873, classifier__learning_rate=0.1565413658703297, classifier__max_bins=104, classifier__max_depth=12, classifier__max_iter=330, classifier__max_leaf_nodes=42, classifier__min_samples_leaf=11; total time=   2.6s
# [CV] END classifier__l2_regularization=0.8500385777897993, classifier__learning_rate=0.09539562808625864, classifier__max_bins=132, classifier__max_depth=9, classifier__max_iter=506, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=9; total time=   3.0s
# [CV] END classifier__l2_regularization=0.8500385777897993, classifier__learning_rate=0.09539562808625864, classifier__max_bins=132, classifier__max_depth=9, classifier__max_iter=506, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=9; total time=   2.8s
# [CV] END classifier__l2_regularization=0.8500385777897993, classifier__learning_rate=0.09539562808625864, classifier__max_bins=132, classifier__max_depth=9, classifier__max_iter=506, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=9; total time=   3.1s
# [CV] END classifier__l2_regularization=0.8500385777897993, classifier__learning_rate=0.09539562808625864, classifier__max_bins=132, classifier__max_depth=9, classifier__max_iter=506, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=9; total time=   2.7s
# [CV] END classifier__l2_regularization=0.8500385777897993, classifier__learning_rate=0.09539562808625864, classifier__max_bins=132, classifier__max_depth=9, classifier__max_iter=506, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=9; total time=   3.2s
# [CV] END classifier__l2_regularization=0.7296061783380641, classifier__learning_rate=0.1311359195574905, classifier__max_bins=134, classifier__max_depth=3, classifier__max_iter=326, classifier__max_leaf_nodes=28, classifier__min_samples_leaf=7; total time=   2.8s
# [CV] END classifier__l2_regularization=0.7296061783380641, classifier__learning_rate=0.1311359195574905, classifier__max_bins=134, classifier__max_depth=3, classifier__max_iter=326, classifier__max_leaf_nodes=28, classifier__min_samples_leaf=7; total time=   3.0s
# [CV] END classifier__l2_regularization=0.7296061783380641, classifier__learning_rate=0.1311359195574905, classifier__max_bins=134, classifier__max_depth=3, classifier__max_iter=326, classifier__max_leaf_nodes=28, classifier__min_samples_leaf=7; total time=   3.0s
# [CV] END classifier__l2_regularization=0.7296061783380641, classifier__learning_rate=0.1311359195574905, classifier__max_bins=134, classifier__max_depth=3, classifier__max_iter=326, classifier__max_leaf_nodes=28, classifier__min_samples_leaf=7; total time=   2.7s
# [CV] END classifier__l2_regularization=0.7296061783380641, classifier__learning_rate=0.1311359195574905, classifier__max_bins=134, classifier__max_depth=3, classifier__max_iter=326, classifier__max_leaf_nodes=28, classifier__min_samples_leaf=7; total time=   3.2s
# [CV] END classifier__l2_regularization=0.7607850486168974, classifier__learning_rate=0.11664266753820428, classifier__max_bins=241, classifier__max_depth=9, classifier__max_iter=382, classifier__max_leaf_nodes=23, classifier__min_samples_leaf=19; total time=   2.8s
# [CV] END classifier__l2_regularization=0.7607850486168974, classifier__learning_rate=0.11664266753820428, classifier__max_bins=241, classifier__max_depth=9, classifier__max_iter=382, classifier__max_leaf_nodes=23, classifier__min_samples_leaf=19; total time=   2.9s
# [CV] END classifier__l2_regularization=0.7607850486168974, classifier__learning_rate=0.11664266753820428, classifier__max_bins=241, classifier__max_depth=9, classifier__max_iter=382, classifier__max_leaf_nodes=23, classifier__min_samples_leaf=19; total time=   3.0s
# [CV] END classifier__l2_regularization=0.7607850486168974, classifier__learning_rate=0.11664266753820428, classifier__max_bins=241, classifier__max_depth=9, classifier__max_iter=382, classifier__max_leaf_nodes=23, classifier__min_samples_leaf=19; total time=   2.9s
# [CV] END classifier__l2_regularization=0.7607850486168974, classifier__learning_rate=0.11664266753820428, classifier__max_bins=241, classifier__max_depth=9, classifier__max_iter=382, classifier__max_leaf_nodes=23, classifier__min_samples_leaf=19; total time=   2.8s
# [CV] END classifier__l2_regularization=0.907566473926093, classifier__learning_rate=0.057365523538286244, classifier__max_bins=242, classifier__max_depth=13, classifier__max_iter=128, classifier__max_leaf_nodes=27, classifier__min_samples_leaf=11; total time=   3.6s
# [CV] END classifier__l2_regularization=0.907566473926093, classifier__learning_rate=0.057365523538286244, classifier__max_bins=242, classifier__max_depth=13, classifier__max_iter=128, classifier__max_leaf_nodes=27, classifier__min_samples_leaf=11; total time=   3.5s
# [CV] END classifier__l2_regularization=0.907566473926093, classifier__learning_rate=0.057365523538286244, classifier__max_bins=242, classifier__max_depth=13, classifier__max_iter=128, classifier__max_leaf_nodes=27, classifier__min_samples_leaf=11; total time=   3.2s
# [CV] END classifier__l2_regularization=0.907566473926093, classifier__learning_rate=0.057365523538286244, classifier__max_bins=242, classifier__max_depth=13, classifier__max_iter=128, classifier__max_leaf_nodes=27, classifier__min_samples_leaf=11; total time=   3.2s
# [CV] END classifier__l2_regularization=0.42754101835854963, classifier__learning_rate=0.014829634081378086, classifier__max_bins=162, classifier__max_depth=9, classifier__max_iter=340, classifier__max_leaf_nodes=46, classifier__min_samples_leaf=8; total time=   4.5s
# [CV] END classifier__l2_regularization=0.907566473926093, classifier__learning_rate=0.057365523538286244, classifier__max_bins=242, classifier__max_depth=13, classifier__max_iter=128, classifier__max_leaf_nodes=27, classifier__min_samples_leaf=11; total time=   3.7s
# [CV] END classifier__l2_regularization=0.42754101835854963, classifier__learning_rate=0.014829634081378086, classifier__max_bins=162, classifier__max_depth=9, classifier__max_iter=340, classifier__max_leaf_nodes=46, classifier__min_samples_leaf=8; total time=   5.9s
# [CV] END classifier__l2_regularization=0.42754101835854963, classifier__learning_rate=0.014829634081378086, classifier__max_bins=162, classifier__max_depth=9, classifier__max_iter=340, classifier__max_leaf_nodes=46, classifier__min_samples_leaf=8; total time=   5.3s
# [CV] END classifier__l2_regularization=0.42754101835854963, classifier__learning_rate=0.014829634081378086, classifier__max_bins=162, classifier__max_depth=9, classifier__max_iter=340, classifier__max_leaf_nodes=46, classifier__min_samples_leaf=8; total time=   6.5s
# [CV] END classifier__l2_regularization=0.42754101835854963, classifier__learning_rate=0.014829634081378086, classifier__max_bins=162, classifier__max_depth=9, classifier__max_iter=340, classifier__max_leaf_nodes=46, classifier__min_samples_leaf=8; total time=   6.7s
# [CV] END classifier__l2_regularization=0.18657005888603584, classifier__learning_rate=0.1795862097130958, classifier__max_bins=174, classifier__max_depth=12, classifier__max_iter=447, classifier__max_leaf_nodes=39, classifier__min_samples_leaf=11; total time=   2.5s
# [CV] END classifier__l2_regularization=0.18657005888603584, classifier__learning_rate=0.1795862097130958, classifier__max_bins=174, classifier__max_depth=12, classifier__max_iter=447, classifier__max_leaf_nodes=39, classifier__min_samples_leaf=11; total time=   2.5s
# [CV] END classifier__l2_regularization=0.18657005888603584, classifier__learning_rate=0.1795862097130958, classifier__max_bins=174, classifier__max_depth=12, classifier__max_iter=447, classifier__max_leaf_nodes=39, classifier__min_samples_leaf=11; total time=   2.4s
# [CV] END classifier__l2_regularization=0.289751452913768, classifier__learning_rate=0.04063204457826084, classifier__max_bins=165, classifier__max_depth=12, classifier__max_iter=144, classifier__max_leaf_nodes=20, classifier__min_samples_leaf=16; total time=   3.3s
# [CV] END classifier__l2_regularization=0.289751452913768, classifier__learning_rate=0.04063204457826084, classifier__max_bins=165, classifier__max_depth=12, classifier__max_iter=144, classifier__max_leaf_nodes=20, classifier__min_samples_leaf=16; total time=   3.5s
# [CV] END classifier__l2_regularization=0.289751452913768, classifier__learning_rate=0.04063204457826084, classifier__max_bins=165, classifier__max_depth=12, classifier__max_iter=144, classifier__max_leaf_nodes=20, classifier__min_samples_leaf=16; total time=   3.8s
# [CV] END classifier__l2_regularization=0.289751452913768, classifier__learning_rate=0.04063204457826084, classifier__max_bins=165, classifier__max_depth=12, classifier__max_iter=144, classifier__max_leaf_nodes=20, classifier__min_samples_leaf=16; total time=   3.7s
# [CV] END classifier__l2_regularization=0.289751452913768, classifier__learning_rate=0.04063204457826084, classifier__max_bins=165, classifier__max_depth=12, classifier__max_iter=144, classifier__max_leaf_nodes=20, classifier__min_samples_leaf=16; total time=   3.6s
# [CV] END classifier__l2_regularization=0.18657005888603584, classifier__learning_rate=0.1795862097130958, classifier__max_bins=174, classifier__max_depth=12, classifier__max_iter=447, classifier__max_leaf_nodes=39, classifier__min_samples_leaf=11; total time=   2.6s
# [CV] END classifier__l2_regularization=0.18657005888603584, classifier__learning_rate=0.1795862097130958, classifier__max_bins=174, classifier__max_depth=12, classifier__max_iter=447, classifier__max_leaf_nodes=39, classifier__min_samples_leaf=11; total time=   2.5s
# [CV] END classifier__l2_regularization=0.906828441545754, classifier__learning_rate=0.06170512738308071, classifier__max_bins=126, classifier__max_depth=11, classifier__max_iter=215, classifier__max_leaf_nodes=27, classifier__min_samples_leaf=13; total time=   2.8s
# [CV] END classifier__l2_regularization=0.906828441545754, classifier__learning_rate=0.06170512738308071, classifier__max_bins=126, classifier__max_depth=11, classifier__max_iter=215, classifier__max_leaf_nodes=27, classifier__min_samples_leaf=13; total time=   2.8s
# [CV] END classifier__l2_regularization=0.906828441545754, classifier__learning_rate=0.06170512738308071, classifier__max_bins=126, classifier__max_depth=11, classifier__max_iter=215, classifier__max_leaf_nodes=27, classifier__min_samples_leaf=13; total time=   3.0s
# [CV] END classifier__l2_regularization=0.906828441545754, classifier__learning_rate=0.06170512738308071, classifier__max_bins=126, classifier__max_depth=11, classifier__max_iter=215, classifier__max_leaf_nodes=27, classifier__min_samples_leaf=13; total time=   3.4s
# [CV] END classifier__l2_regularization=0.906828441545754, classifier__learning_rate=0.06170512738308071, classifier__max_bins=126, classifier__max_depth=11, classifier__max_iter=215, classifier__max_leaf_nodes=27, classifier__min_samples_leaf=13; total time=   3.3s
# [CV] END classifier__l2_regularization=0.30478125815802903, classifier__learning_rate=0.04128461209715893, classifier__max_bins=254, classifier__max_depth=11, classifier__max_iter=417, classifier__max_leaf_nodes=47, classifier__min_samples_leaf=23; total time=   3.2s
# [CV] END classifier__l2_regularization=0.30478125815802903, classifier__learning_rate=0.04128461209715893, classifier__max_bins=254, classifier__max_depth=11, classifier__max_iter=417, classifier__max_leaf_nodes=47, classifier__min_samples_leaf=23; total time=   3.8s
# [CV] END classifier__l2_regularization=0.30478125815802903, classifier__learning_rate=0.04128461209715893, classifier__max_bins=254, classifier__max_depth=11, classifier__max_iter=417, classifier__max_leaf_nodes=47, classifier__min_samples_leaf=23; total time=   3.9s
# [CV] END classifier__l2_regularization=0.30478125815802903, classifier__learning_rate=0.04128461209715893, classifier__max_bins=254, classifier__max_depth=11, classifier__max_iter=417, classifier__max_leaf_nodes=47, classifier__min_samples_leaf=23; total time=   3.0s
# [CV] END classifier__l2_regularization=0.30478125815802903, classifier__learning_rate=0.04128461209715893, classifier__max_bins=254, classifier__max_depth=11, classifier__max_iter=417, classifier__max_leaf_nodes=47, classifier__min_samples_leaf=23; total time=   3.9s
# [CV] END classifier__l2_regularization=0.2694123337985215, classifier__learning_rate=0.05638384922707709, classifier__max_bins=158, classifier__max_depth=8, classifier__max_iter=259, classifier__max_leaf_nodes=46, classifier__min_samples_leaf=28; total time=   3.1s
# [CV] END classifier__l2_regularization=0.2694123337985215, classifier__learning_rate=0.05638384922707709, classifier__max_bins=158, classifier__max_depth=8, classifier__max_iter=259, classifier__max_leaf_nodes=46, classifier__min_samples_leaf=28; total time=   3.4s
# [CV] END classifier__l2_regularization=0.2694123337985215, classifier__learning_rate=0.05638384922707709, classifier__max_bins=158, classifier__max_depth=8, classifier__max_iter=259, classifier__max_leaf_nodes=46, classifier__min_samples_leaf=28; total time=   3.1s
# [CV] END classifier__l2_regularization=0.2694123337985215, classifier__learning_rate=0.05638384922707709, classifier__max_bins=158, classifier__max_depth=8, classifier__max_iter=259, classifier__max_leaf_nodes=46, classifier__min_samples_leaf=28; total time=   2.9s
# [CV] END classifier__l2_regularization=0.2694123337985215, classifier__learning_rate=0.05638384922707709, classifier__max_bins=158, classifier__max_depth=8, classifier__max_iter=259, classifier__max_leaf_nodes=46, classifier__min_samples_leaf=28; total time=   3.3s
# [CV] END classifier__l2_regularization=0.7030189588951778, classifier__learning_rate=0.07908962445206585, classifier__max_bins=151, classifier__max_depth=14, classifier__max_iter=394, classifier__max_leaf_nodes=16, classifier__min_samples_leaf=7; total time=   3.1s
# [CV] END classifier__l2_regularization=0.7030189588951778, classifier__learning_rate=0.07908962445206585, classifier__max_bins=151, classifier__max_depth=14, classifier__max_iter=394, classifier__max_leaf_nodes=16, classifier__min_samples_leaf=7; total time=   3.1s
# [CV] END classifier__l2_regularization=0.7030189588951778, classifier__learning_rate=0.07908962445206585, classifier__max_bins=151, classifier__max_depth=14, classifier__max_iter=394, classifier__max_leaf_nodes=16, classifier__min_samples_leaf=7; total time=   2.9s
# [CV] END classifier__l2_regularization=0.7030189588951778, classifier__learning_rate=0.07908962445206585, classifier__max_bins=151, classifier__max_depth=14, classifier__max_iter=394, classifier__max_leaf_nodes=16, classifier__min_samples_leaf=7; total time=   3.0s
# [CV] END classifier__l2_regularization=0.7030189588951778, classifier__learning_rate=0.07908962445206585, classifier__max_bins=151, classifier__max_depth=14, classifier__max_iter=394, classifier__max_leaf_nodes=16, classifier__min_samples_leaf=7; total time=   3.2s
# [CV] END classifier__l2_regularization=0.30087830981676966, classifier__learning_rate=0.06411969393171885, classifier__max_bins=180, classifier__max_depth=13, classifier__max_iter=212, classifier__max_leaf_nodes=16, classifier__min_samples_leaf=6; total time=   3.1s
# [CV] END classifier__l2_regularization=0.30087830981676966, classifier__learning_rate=0.06411969393171885, classifier__max_bins=180, classifier__max_depth=13, classifier__max_iter=212, classifier__max_leaf_nodes=16, classifier__min_samples_leaf=6; total time=   3.2s
# [CV] END classifier__l2_regularization=0.30087830981676966, classifier__learning_rate=0.06411969393171885, classifier__max_bins=180, classifier__max_depth=13, classifier__max_iter=212, classifier__max_leaf_nodes=16, classifier__min_samples_leaf=6; total time=   3.3s
# [CV] END classifier__l2_regularization=0.30087830981676966, classifier__learning_rate=0.06411969393171885, classifier__max_bins=180, classifier__max_depth=13, classifier__max_iter=212, classifier__max_leaf_nodes=16, classifier__min_samples_leaf=6; total time=   3.2s
# [CV] END classifier__l2_regularization=0.30087830981676966, classifier__learning_rate=0.06411969393171885, classifier__max_bins=180, classifier__max_depth=13, classifier__max_iter=212, classifier__max_leaf_nodes=16, classifier__min_samples_leaf=6; total time=   3.7s
# [CV] END classifier__l2_regularization=0.489452760277563, classifier__learning_rate=0.19727358628101416, classifier__max_bins=167, classifier__max_depth=9, classifier__max_iter=302, classifier__max_leaf_nodes=31, classifier__min_samples_leaf=10; total time=   2.7s
# [CV] END classifier__l2_regularization=0.489452760277563, classifier__learning_rate=0.19727358628101416, classifier__max_bins=167, classifier__max_depth=9, classifier__max_iter=302, classifier__max_leaf_nodes=31, classifier__min_samples_leaf=10; total time=   2.5s
# [CV] END classifier__l2_regularization=0.489452760277563, classifier__learning_rate=0.19727358628101416, classifier__max_bins=167, classifier__max_depth=9, classifier__max_iter=302, classifier__max_leaf_nodes=31, classifier__min_samples_leaf=10; total time=   2.5s
# [CV] END classifier__l2_regularization=0.489452760277563, classifier__learning_rate=0.19727358628101416, classifier__max_bins=167, classifier__max_depth=9, classifier__max_iter=302, classifier__max_leaf_nodes=31, classifier__min_samples_leaf=10; total time=   2.5s
# [CV] END classifier__l2_regularization=0.489452760277563, classifier__learning_rate=0.19727358628101416, classifier__max_bins=167, classifier__max_depth=9, classifier__max_iter=302, classifier__max_leaf_nodes=31, classifier__min_samples_leaf=10; total time=   2.5s
# [CV] END classifier__l2_regularization=0.4110370133182313, classifier__learning_rate=0.01627963925110419, classifier__max_bins=228, classifier__max_depth=5, classifier__max_iter=225, classifier__max_leaf_nodes=16, classifier__min_samples_leaf=25; total time=   5.4s
# [CV] END classifier__l2_regularization=0.4110370133182313, classifier__learning_rate=0.01627963925110419, classifier__max_bins=228, classifier__max_depth=5, classifier__max_iter=225, classifier__max_leaf_nodes=16, classifier__min_samples_leaf=25; total time=   5.0s
# [CV] END classifier__l2_regularization=0.4110370133182313, classifier__learning_rate=0.01627963925110419, classifier__max_bins=228, classifier__max_depth=5, classifier__max_iter=225, classifier__max_leaf_nodes=16, classifier__min_samples_leaf=25; total time=   6.2s
# [CV] END classifier__l2_regularization=0.4110370133182313, classifier__learning_rate=0.01627963925110419, classifier__max_bins=228, classifier__max_depth=5, classifier__max_iter=225, classifier__max_leaf_nodes=16, classifier__min_samples_leaf=25; total time=   6.3s
# [CV] END classifier__l2_regularization=0.4110370133182313, classifier__learning_rate=0.01627963925110419, classifier__max_bins=228, classifier__max_depth=5, classifier__max_iter=225, classifier__max_leaf_nodes=16, classifier__min_samples_leaf=25; total time=   6.5s
# [CV] END classifier__l2_regularization=0.3677831327192532, classifier__learning_rate=0.1301381078127801, classifier__max_bins=238, classifier__max_depth=3, classifier__max_iter=300, classifier__max_leaf_nodes=20, classifier__min_samples_leaf=20; total time=   2.6s
# [CV] END classifier__l2_regularization=0.3677831327192532, classifier__learning_rate=0.1301381078127801, classifier__max_bins=238, classifier__max_depth=3, classifier__max_iter=300, classifier__max_leaf_nodes=20, classifier__min_samples_leaf=20; total time=   2.5s
# [CV] END classifier__l2_regularization=0.3677831327192532, classifier__learning_rate=0.1301381078127801, classifier__max_bins=238, classifier__max_depth=3, classifier__max_iter=300, classifier__max_leaf_nodes=20, classifier__min_samples_leaf=20; total time=   2.7s
# [CV] END classifier__l2_regularization=0.3677831327192532, classifier__learning_rate=0.1301381078127801, classifier__max_bins=238, classifier__max_depth=3, classifier__max_iter=300, classifier__max_leaf_nodes=20, classifier__min_samples_leaf=20; total time=   2.7s
# [CV] END classifier__l2_regularization=0.3677831327192532, classifier__learning_rate=0.1301381078127801, classifier__max_bins=238, classifier__max_depth=3, classifier__max_iter=300, classifier__max_leaf_nodes=20, classifier__min_samples_leaf=20; total time=   2.7s
# [CV] END classifier__l2_regularization=0.040775141554763916, classifier__learning_rate=0.12226965920576593, classifier__max_bins=246, classifier__max_depth=12, classifier__max_iter=550, classifier__max_leaf_nodes=33, classifier__min_samples_leaf=24; total time=   2.7s
# [CV] END classifier__l2_regularization=0.040775141554763916, classifier__learning_rate=0.12226965920576593, classifier__max_bins=246, classifier__max_depth=12, classifier__max_iter=550, classifier__max_leaf_nodes=33, classifier__min_samples_leaf=24; total time=   2.7s
# [CV] END classifier__l2_regularization=0.040775141554763916, classifier__learning_rate=0.12226965920576593, classifier__max_bins=246, classifier__max_depth=12, classifier__max_iter=550, classifier__max_leaf_nodes=33, classifier__min_samples_leaf=24; total time=   2.9s
# [CV] END classifier__l2_regularization=0.040775141554763916, classifier__learning_rate=0.12226965920576593, classifier__max_bins=246, classifier__max_depth=12, classifier__max_iter=550, classifier__max_leaf_nodes=33, classifier__min_samples_leaf=24; total time=   2.8s
# [CV] END classifier__l2_regularization=0.040775141554763916, classifier__learning_rate=0.12226965920576593, classifier__max_bins=246, classifier__max_depth=12, classifier__max_iter=550, classifier__max_leaf_nodes=33, classifier__min_samples_leaf=24; total time=   2.7s
# [CV] END classifier__l2_regularization=0.6451727904094499, classifier__learning_rate=0.043129621510948374, classifier__max_bins=227, classifier__max_depth=9, classifier__max_iter=437, classifier__max_leaf_nodes=15, classifier__min_samples_leaf=15; total time=   3.6s
# [CV] END classifier__l2_regularization=0.6451727904094499, classifier__learning_rate=0.043129621510948374, classifier__max_bins=227, classifier__max_depth=9, classifier__max_iter=437, classifier__max_leaf_nodes=15, classifier__min_samples_leaf=15; total time=   3.8s
# [CV] END classifier__l2_regularization=0.6451727904094499, classifier__learning_rate=0.043129621510948374, classifier__max_bins=227, classifier__max_depth=9, classifier__max_iter=437, classifier__max_leaf_nodes=15, classifier__min_samples_leaf=15; total time=   3.8s
# [CV] END classifier__l2_regularization=0.6451727904094499, classifier__learning_rate=0.043129621510948374, classifier__max_bins=227, classifier__max_depth=9, classifier__max_iter=437, classifier__max_leaf_nodes=15, classifier__min_samples_leaf=15; total time=   3.9s
# [CV] END classifier__l2_regularization=0.6451727904094499, classifier__learning_rate=0.043129621510948374, classifier__max_bins=227, classifier__max_depth=9, classifier__max_iter=437, classifier__max_leaf_nodes=15, classifier__min_samples_leaf=15; total time=   4.7s
# [CV] END classifier__l2_regularization=0.3410663510502585, classifier__learning_rate=0.03155996903571193, classifier__max_bins=250, classifier__max_depth=12, classifier__max_iter=198, classifier__max_leaf_nodes=21, classifier__min_samples_leaf=20; total time=   4.6s
# [CV] END classifier__l2_regularization=0.3410663510502585, classifier__learning_rate=0.03155996903571193, classifier__max_bins=250, classifier__max_depth=12, classifier__max_iter=198, classifier__max_leaf_nodes=21, classifier__min_samples_leaf=20; total time=   4.2s
# [CV] END classifier__l2_regularization=0.3410663510502585, classifier__learning_rate=0.03155996903571193, classifier__max_bins=250, classifier__max_depth=12, classifier__max_iter=198, classifier__max_leaf_nodes=21, classifier__min_samples_leaf=20; total time=   4.6s
# [CV] END classifier__l2_regularization=0.8172222002012158, classifier__learning_rate=0.11548815420389784, classifier__max_bins=159, classifier__max_depth=3, classifier__max_iter=101, classifier__max_leaf_nodes=15, classifier__min_samples_leaf=20; total time=   3.0s
# [CV] END classifier__l2_regularization=0.3410663510502585, classifier__learning_rate=0.03155996903571193, classifier__max_bins=250, classifier__max_depth=12, classifier__max_iter=198, classifier__max_leaf_nodes=21, classifier__min_samples_leaf=20; total time=   4.6s
# [CV] END classifier__l2_regularization=0.3410663510502585, classifier__learning_rate=0.03155996903571193, classifier__max_bins=250, classifier__max_depth=12, classifier__max_iter=198, classifier__max_leaf_nodes=21, classifier__min_samples_leaf=20; total time=   4.4s
# [CV] END classifier__l2_regularization=0.8172222002012158, classifier__learning_rate=0.11548815420389784, classifier__max_bins=159, classifier__max_depth=3, classifier__max_iter=101, classifier__max_leaf_nodes=15, classifier__min_samples_leaf=20; total time=   3.2s
# [CV] END classifier__l2_regularization=0.8172222002012158, classifier__learning_rate=0.11548815420389784, classifier__max_bins=159, classifier__max_depth=3, classifier__max_iter=101, classifier__max_leaf_nodes=15, classifier__min_samples_leaf=20; total time=   3.1s
# [CV] END classifier__l2_regularization=0.8172222002012158, classifier__learning_rate=0.11548815420389784, classifier__max_bins=159, classifier__max_depth=3, classifier__max_iter=101, classifier__max_leaf_nodes=15, classifier__min_samples_leaf=20; total time=   3.1s
# [CV] END classifier__l2_regularization=0.8172222002012158, classifier__learning_rate=0.11548815420389784, classifier__max_bins=159, classifier__max_depth=3, classifier__max_iter=101, classifier__max_leaf_nodes=15, classifier__min_samples_leaf=20; total time=   3.0s
# [CV] END classifier__l2_regularization=0.9654193512887936, classifier__learning_rate=0.11607575618534854, classifier__max_bins=108, classifier__max_depth=11, classifier__max_iter=198, classifier__max_leaf_nodes=33, classifier__min_samples_leaf=20; total time=   2.7s
# [CV] END classifier__l2_regularization=0.9654193512887936, classifier__learning_rate=0.11607575618534854, classifier__max_bins=108, classifier__max_depth=11, classifier__max_iter=198, classifier__max_leaf_nodes=33, classifier__min_samples_leaf=20; total time=   2.9s
# [CV] END classifier__l2_regularization=0.9654193512887936, classifier__learning_rate=0.11607575618534854, classifier__max_bins=108, classifier__max_depth=11, classifier__max_iter=198, classifier__max_leaf_nodes=33, classifier__min_samples_leaf=20; total time=   2.9s
# [CV] END classifier__l2_regularization=0.9654193512887936, classifier__learning_rate=0.11607575618534854, classifier__max_bins=108, classifier__max_depth=11, classifier__max_iter=198, classifier__max_leaf_nodes=33, classifier__min_samples_leaf=20; total time=   2.6s
# [CV] END classifier__l2_regularization=0.9654193512887936, classifier__learning_rate=0.11607575618534854, classifier__max_bins=108, classifier__max_depth=11, classifier__max_iter=198, classifier__max_leaf_nodes=33, classifier__min_samples_leaf=20; total time=   3.0s
# [CV] END classifier__l2_regularization=0.8466611422383059, classifier__learning_rate=0.17270161545683757, classifier__max_bins=153, classifier__max_depth=10, classifier__max_iter=260, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=24; total time=   2.7s
# [CV] END classifier__l2_regularization=0.8466611422383059, classifier__learning_rate=0.17270161545683757, classifier__max_bins=153, classifier__max_depth=10, classifier__max_iter=260, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=24; total time=   2.6s
# [CV] END classifier__l2_regularization=0.8466611422383059, classifier__learning_rate=0.17270161545683757, classifier__max_bins=153, classifier__max_depth=10, classifier__max_iter=260, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=24; total time=   2.8s
# [CV] END classifier__l2_regularization=0.8466611422383059, classifier__learning_rate=0.17270161545683757, classifier__max_bins=153, classifier__max_depth=10, classifier__max_iter=260, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=24; total time=   2.7s
# [CV] END classifier__l2_regularization=0.8466611422383059, classifier__learning_rate=0.17270161545683757, classifier__max_bins=153, classifier__max_depth=10, classifier__max_iter=260, classifier__max_leaf_nodes=38, classifier__min_samples_leaf=24; total time=   2.8s
# [CV] END classifier__l2_regularization=0.1014715428660321, classifier__learning_rate=0.13606533613053062, classifier__max_bins=192, classifier__max_depth=4, classifier__max_iter=483, classifier__max_leaf_nodes=32, classifier__min_samples_leaf=6; total time=   2.8s
# [CV] END classifier__l2_regularization=0.08413996499504883, classifier__learning_rate=0.04070945567797662, classifier__max_bins=203, classifier__max_depth=6, classifier__max_iter=353, classifier__max_leaf_nodes=49, classifier__min_samples_leaf=20; total time=   3.6s
# [CV] END classifier__l2_regularization=0.1014715428660321, classifier__learning_rate=0.13606533613053062, classifier__max_bins=192, classifier__max_depth=4, classifier__max_iter=483, classifier__max_leaf_nodes=32, classifier__min_samples_leaf=6; total time=   2.8s
# [CV] END classifier__l2_regularization=0.08413996499504883, classifier__learning_rate=0.04070945567797662, classifier__max_bins=203, classifier__max_depth=6, classifier__max_iter=353, classifier__max_leaf_nodes=49, classifier__min_samples_leaf=20; total time=   4.2s
# [CV] END classifier__l2_regularization=0.1014715428660321, classifier__learning_rate=0.13606533613053062, classifier__max_bins=192, classifier__max_depth=4, classifier__max_iter=483, classifier__max_leaf_nodes=32, classifier__min_samples_leaf=6; total time=   2.9s
# [CV] END classifier__l2_regularization=0.08413996499504883, classifier__learning_rate=0.04070945567797662, classifier__max_bins=203, classifier__max_depth=6, classifier__max_iter=353, classifier__max_leaf_nodes=49, classifier__min_samples_leaf=20; total time=   4.6s
# [CV] END classifier__l2_regularization=0.08413996499504883, classifier__learning_rate=0.04070945567797662, classifier__max_bins=203, classifier__max_depth=6, classifier__max_iter=353, classifier__max_leaf_nodes=49, classifier__min_samples_leaf=20; total time=   3.8s
# [CV] END classifier__l2_regularization=0.08413996499504883, classifier__learning_rate=0.04070945567797662, classifier__max_bins=203, classifier__max_depth=6, classifier__max_iter=353, classifier__max_leaf_nodes=49, classifier__min_samples_leaf=20; total time=   4.0s
# [CV] END classifier__l2_regularization=0.1014715428660321, classifier__learning_rate=0.13606533613053062, classifier__max_bins=192, classifier__max_depth=4, classifier__max_iter=483, classifier__max_leaf_nodes=32, classifier__min_samples_leaf=6; total time=   2.6s
# [CV] END classifier__l2_regularization=0.1014715428660321, classifier__learning_rate=0.13606533613053062, classifier__max_bins=192, classifier__max_depth=4, classifier__max_iter=483, classifier__max_leaf_nodes=32, classifier__min_samples_leaf=6; total time=   3.1s
# [CV] END classifier__l2_regularization=0.6918951976926933, classifier__learning_rate=0.13387263930549412, classifier__max_bins=167, classifier__max_depth=3, classifier__max_iter=497, classifier__max_leaf_nodes=35, classifier__min_samples_leaf=20; total time=   2.8s
# [CV] END classifier__l2_regularization=0.6918951976926933, classifier__learning_rate=0.13387263930549412, classifier__max_bins=167, classifier__max_depth=3, classifier__max_iter=497, classifier__max_leaf_nodes=35, classifier__min_samples_leaf=20; total time=   3.1s
# [CV] END classifier__l2_regularization=0.6918951976926933, classifier__learning_rate=0.13387263930549412, classifier__max_bins=167, classifier__max_depth=3, classifier__max_iter=497, classifier__max_leaf_nodes=35, classifier__min_samples_leaf=20; total time=   2.9s
# [CV] END classifier__l2_regularization=0.6918951976926933, classifier__learning_rate=0.13387263930549412, classifier__max_bins=167, classifier__max_depth=3, classifier__max_iter=497, classifier__max_leaf_nodes=35, classifier__min_samples_leaf=20; total time=   2.8s
# [CV] END classifier__l2_regularization=0.7464914051180241, classifier__learning_rate=0.13343025081897078, classifier__max_bins=234, classifier__max_depth=5, classifier__max_iter=500, classifier__max_leaf_nodes=47, classifier__min_samples_leaf=20; total time=   2.8s
# [CV] END classifier__l2_regularization=0.6918951976926933, classifier__learning_rate=0.13387263930549412, classifier__max_bins=167, classifier__max_depth=3, classifier__max_iter=497, classifier__max_leaf_nodes=35, classifier__min_samples_leaf=20; total time=   3.2s
# [CV] END classifier__l2_regularization=0.7464914051180241, classifier__learning_rate=0.13343025081897078, classifier__max_bins=234, classifier__max_depth=5, classifier__max_iter=500, classifier__max_leaf_nodes=47, classifier__min_samples_leaf=20; total time=   2.9s
# [CV] END classifier__l2_regularization=0.7464914051180241, classifier__learning_rate=0.13343025081897078, classifier__max_bins=234, classifier__max_depth=5, classifier__max_iter=500, classifier__max_leaf_nodes=47, classifier__min_samples_leaf=20; total time=   2.8s
# [CV] END classifier__l2_regularization=0.7464914051180241, classifier__learning_rate=0.13343025081897078, classifier__max_bins=234, classifier__max_depth=5, classifier__max_iter=500, classifier__max_leaf_nodes=47, classifier__min_samples_leaf=20; total time=   2.6s
# [CV] END classifier__l2_regularization=0.7464914051180241, classifier__learning_rate=0.13343025081897078, classifier__max_bins=234, classifier__max_depth=5, classifier__max_iter=500, classifier__max_leaf_nodes=47, classifier__min_samples_leaf=20; total time=   3.0s
# [CV] END classifier__l2_regularization=0.09367476782809248, classifier__learning_rate=0.07986600258129237, classifier__max_bins=218, classifier__max_depth=8, classifier__max_iter=337, classifier__max_leaf_nodes=44, classifier__min_samples_leaf=10; total time=   2.6s
# [CV] END classifier__l2_regularization=0.09367476782809248, classifier__learning_rate=0.07986600258129237, classifier__max_bins=218, classifier__max_depth=8, classifier__max_iter=337, classifier__max_leaf_nodes=44, classifier__min_samples_leaf=10; total time=   2.3s
# [CV] END classifier__l2_regularization=0.09367476782809248, classifier__learning_rate=0.07986600258129237, classifier__max_bins=218, classifier__max_depth=8, classifier__max_iter=337, classifier__max_leaf_nodes=44, classifier__min_samples_leaf=10; total time=   2.6s
# [CV] END classifier__l2_regularization=0.09367476782809248, classifier__learning_rate=0.07986600258129237, classifier__max_bins=218, classifier__max_depth=8, classifier__max_iter=337, classifier__max_leaf_nodes=44, classifier__min_samples_leaf=10; total time=   2.8s
# [CV] END classifier__l2_regularization=0.09367476782809248, classifier__learning_rate=0.07986600258129237, classifier__max_bins=218, classifier__max_depth=8, classifier__max_iter=337, classifier__max_leaf_nodes=44, classifier__min_samples_leaf=10; total time=   2.7s
# Best Parameters: {'classifier__l2_regularization': np.float64(0.9611720243493491), 'classifier__learning_rate': np.float64(0.17046143124884877), 'classifier__max_bins': 181, 'classifier__max_depth': 7, 'classifier__max_iter': 379, 'classifier__max_leaf_nodes': 40, 'classifier__min_samples_leaf': 29}
# Best Cross-Validation Recall@FPR=0.1%: 0.31645569620253167

# %%
import numpy as np
from sklearn.model_selection import cross_val_predict

best_model = random_search.best_estimator_

oof_proba = cross_val_predict(
    best_model,
    X_train, y_train,
    cv=skf,
    method="predict_proba",
    params={"classifier__sample_weight": sample_weight},
)[:, 1]

# --- Verify lengths ---
assert len(oof_proba) == len(y_train)

# --- Choose threshold ---
chosen_thr, strategy, metrics = choose_threshold_max_recall_at_fpr(
    y_true=y_train,
    proba=oof_proba,
    max_fpr=0.001
)

# %%
print(f"Chosen threshold after hyperparameter tuning: {chosen_thr}, strategy: {strategy}")

for metric_name, metric_value in metrics.items():
    print(f"{metric_name}: {metric_value:.4f}")

cm = confusion_matrix(y_train, (oof_proba >= chosen_thr).astype(int))
print("Confusion Matrix after hyperparameter tuning:\n", cm)

#save the model
joblib.dump(best_model, MODELS_DIR / "hgb_params.json")
# Out:
# Chosen threshold after hyperparameter tuning: 0.6244207423852489, strategy: Max recall with FPR≤0.0010
# threshold: 0.6244
# fpr: 0.0009
# recall: 0.8198
# precision: 0.6049
# f1: 0.6961
# Confusion Matrix after hyperparameter tuning:
#  [[227240    211]
#  [    71    323]]
# ['/Users/uvlazhnitel/Documents/coding/DataScience/Credit-Card-Fraud/models/hgb_params.json']

# %%
precision_tuned, recall_tuned, thresholds_tuned = precision_recall_curve(y_train, oof_proba)
plt.figure(figsize=(8, 6))
plt.plot(recall_tuned, precision_tuned, label="Precision-Recall Curve")
plt.scatter(metrics['recall'], metrics['precision'], color='red', label='Chosen Threshold', zorder=5)
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve with Chosen Threshold (Tuned HGB)")
plt.legend()
plt.grid()
plt.savefig(REPORTS_DIR / "pr_curve_chosen_threshold_hgb_tuned.png")
plt.show()

thr_ext_tuned = np.r_[0.0, thresholds_tuned]
plt.figure(figsize=(8, 6))
plt.plot(thr_ext_tuned, recall_tuned, label="Recall vs Threshold")
plt.scatter(chosen_thr, metrics['recall'], color='red', label='Chosen Threshold', zorder=5)
plt.xlabel("Threshold"); plt.ylabel("Recall")
plt.title("Recall vs Threshold with Chosen Threshold (Tuned HGB)")
plt.legend()
plt.grid()
plt.savefig(REPORTS_DIR / "recall_vs_threshold_chosen_threshold_hgb_tuned.png")
